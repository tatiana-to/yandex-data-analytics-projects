# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Татьяна, привет!</b>
#
# Меня зовут Евгений Дащенко, и я буду проверять твой проект. Предлагаю общаться на «ты» 😊 Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Критическая ошибка:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Хорошо, но можно и лучше:</b> Так выделены небольшие замечания. Одна-два таких замечания в проекте допустимы, но если их будет больше - тебе будет необходимо внести исправления. Это как тестовое задание при приеме на работу: очень много мелких ошибок могут стать причиной отказа кандидату.
#
# </div>
#
# <div class="alert alert-success">
# <b>Все отлично:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Замена-типа-данных" data-toc-modified-id="Замена-типа-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Замена типа данных</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здорово, когда есть вступление в сам проект, каждый сможет быстрее разобраться в концепции / деталях работы.
#
# </div>

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# Для начала прочитаем файл и сохраним его в переменнной data и выведем на экран первые 10 строк таблицы.
# Первый взгляд на сырые данные - это важная часть любого исследования.

# %%
import pandas as pd
import matplotlib.pyplot as plt 

data = pd.read_csv('/datasets/real_estate_data.csv') 
display(data.head(10))
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...
# 5  10\t2890000.0\t30.4\t2018-09-10T00:00:00\t1\t\...
# 6  6\t3700000.0\t37.3\t2017-11-02T00:00:00\t1\t\t...
# 7  5\t7915000.0\t71.6\t2019-04-18T00:00:00\t2\t\t...
# 8  20\t2900000.0\t33.16\t2018-05-23T00:00:00\t1\t...
# 9  18\t5400000.0\t61.0\t2017-02-26T00:00:00\t3\t2...

# %% [markdown]
# Итак, что мы имеем -склееные данные, которые необходимо разбить по колонкам

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')  # в качестве разделителя указываем знак табуляции \t
display(data.head())
data.info() #получение общей информации о данных в таблице
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Согласно приведенной выше информации имеем таблицу, в которой 22 колонки и 23699 строки, типы данных : целые числа, дробные числа, текстовые данные и даже булевы значения. Можно отметить, что количество значений в столбцах различается, а это значит что в данных есть пропущенные значения, также в названии одной из колонок есть расхождение с хорошим стилем.
# Займемся предобработкой данных и устраним проблемы.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Первичные данные посмотрели, давай теперь их обработаем, ведь у нас есть план 😊.
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Исправим стиль заголовка в колонке cityCenters_nearest, приведем к змеиному регистру.

# %%
data = data.rename(columns={'cityCenters_nearest' : 'city_centers_nearest'})

# %%
data.columns #проверим результат
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Хороший и безопасный способ заменить названия в нашем датафрейме.
# </div>

# %% [markdown]
# Теперь займемся пропусками. Посчитаем сколько в таблице пропущенных значений.

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# В некоторых колонках пропущенных значений достаточно много, необходимо определить какими данными мы будем заполнять пропущенные значения, какие колонки нас интересуют больше всего, какие не интересуют вообще.
# Рассмотрим каждую колонку отдельно. Первое что можно сделать это заполнить пропущенные значения в колонке balcony, скорее всего в квартире нет балкона и владелец не заполнил это поле, поэтому все пропущенные значения можно заменить на 0.

# %%
data['balcony'] = data['balcony'].fillna(0)
data['balcony'].isna().sum() #подсчет пропусков после заполнения
# Out:
# 0

# %% [markdown]
# Дальше рассмотрим колонку floors_total. Прпопусков не так много всего 86, поэтому можно их просто исключить, при анализе данных они нам не пригодятся.

# %%
data.dropna(subset=['floors_total'], inplace=True)# удаяем пропущенные значения 
print(data['floors_total'].isna().sum())# выводим результат после удаления
# Out:
# 0

# %% [markdown]
# Рассмотрим колонку is_apartment. Выведем данные которые содержит колонка.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# Я бы рекомендовал не использовать атрибут `inplace`, так как в последующих обновлениях библотеки `pandas` он будет удален.
#
# Лучше всего переопределять переменные.
#
# </div>

# %%
print(data['is_apartment'].unique())# используем метод для просмотра уникальных значений.
# Out:
# [nan False True]

# %% [markdown]
# Заполним пропуски на False, так как в проекте мы рассматриваем категорию "квартиры", а "апартаменты" это другая категория жилья.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)
data['is_apartment'].isna().sum() # выводим результат после заполнения
# Out:
# 0

# %% [markdown]
# Далее рассмотрим колонку ceiling_height. Пропущенных значений достаточно много и к тому же в исследовательском анализе нам нужны данные из этой колонки, поэтому заполним их медианой

# %%
data.loc[data['ceiling_height'].isna(), 'ceiling_height'] = data['ceiling_height'].median() # заполняем медианой, применяя метод логической индексации
data['ceiling_height'].isna().sum()# выводим количество пропусков после заполнения
# Out:
# 0

# %% [markdown]
# Разберемся с колонкой locality_name. Пропущенных значений всего 49, их можно удалить.

# %%
data.dropna(subset=['locality_name'], inplace=True)# удаяем пропущенные значения 
print(data['locality_name'].isna().sum())
# Out:
# 0

# %% [markdown]
# Посмотрим какие названия содержит колонка.

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Названий населенных пунктов огромное количество, причем есть одинаковые названия, но с разным написанием... Решено,чтобы не было путаницы оставим только названия нас.пунктов без принадлежности к определенному типу.

# %%
type_locality_name=['посёлок', 'городской', 'деревня',
                    'городского', 'типа', 'поселок', 'садовое', 'товарищество', 
                    'село', 'садоводческое', 'некоммерческое', 'товарищество', 'коттеджный','при', 'железнодорожной' ] #делаем список для слов, от которых мы хотим избавится.

for name in type_locality_name: # создадим цикл, которым пройдемся по всему списку
    data['locality_name'] = data['locality_name'].str.replace(name, '')
data['locality_name'] = data['locality_name'].str.lstrip() # методом strip() избавимся от пробелов, которые могли образоваться после удаления слов.

print(data['locality_name'].unique()) # выводим результат
# Out:
# ['Санкт-Петербург' 'Шушары' 'Янино-1' 'Парголово' 'Мурино' 'Ломоносов'
#  'Сертолово' 'Петергоф' 'Пушкин' 'Кудрово' 'Коммунар' 'Колпино'
#  'Красный Бор' 'Гатчина' 'Фёдоровское' 'Выборг' 'Кронштадт' 'Кировск'
#  'Новое Девяткино' 'Металлострой' 'Лебяжье' 'Сиверский' 'Молодцово'
#  'Кузьмоловский' 'Новая Ропша' 'Павловск' 'Пикколово' 'Всеволожск'
#  'Волхов' 'Кингисепп' 'Приозерск' 'Сестрорецк' 'Куттузи' 'Аннино'
#  'Ефимовский' 'Плодовое' 'Заклинье' 'Торковичи' 'Первомайское'
#  'Красное Село' 'Понтонный' 'Сясьстрой' 'Старая' 'Лесколово' 'Новый Свет'
#  'Сланцы' 'Путилово' 'Ивангород' 'Шлиссельбург' 'Никольское' 'Зеленогорск'
#  'Сосновый Бор' 'Оржицы' 'Кальтино' 'Романовка' 'Бугры' 'Рощино' 'Кириши'
#  'Луга' 'Волосово' 'Отрадное' 'Павлово' 'Оредеж' 'Копорье' 'Молодёжное'
#  'Тихвин' 'Победа' 'Нурма' 'Синявино' 'Тосно' 'Стрельна' 'Бокситогорск'
#  'Александровская' 'Лопухинка' 'Пикалёво' 'Терволово' 'Советский'
# ...

# %% [markdown]
# Теперь для того чтобы заполнить значения в колонках airports_nearest, city_centers_nearest, parks_around3000, parks_nearest ,ponds_around3000 ,ponds_nearest , сгруппируем данные по колонке locality_name  высчитаем медиану в каждой группе и заполним пропуски. Там где невозможно вычислить медиану в группе, заполним пропуски медианным значением по всему набору данных.

# %%
groups = data.groupby('locality_name') #сохраним в переменной группировку по названиям нас.пунктов
for name, group in groups: #пройдемся циклом по группам
    airports_rows = group.query('airports_nearest > 0') #с помощью метода query найдем группы, в которых данные для вычесления медианы есть и сохраним в переменной  
    if len(airports_rows) > 0: #проверяем, если есть в этой группе данные по расстоянию
        group_median = airports_rows['airports_nearest'].median() #высчитываем медиану для группы 
        data.loc[(data['locality_name'] == name) & (data['airports_nearest'].isna()), 'airports_nearest'] = group_median #заполняем медианой группы
        

data.loc[data['airports_nearest'].isna(), 'airports_nearest'] = data['airports_nearest'].median() # заполняем общей медианой все оставшиеся пропуски , применяя метод логической индексации

data['airports_nearest'].isna().sum() #проверяем результат нашего заполнения пропусков
# Out:
# 0

# %% [markdown]
# Тоже самое делаем и с остальными колонками

# %%
groups = data.groupby('locality_name')
for name, group in groups:
    city_centers_rows = group.query('city_centers_nearest > 0')
    if len(city_centers_rows) > 0: #проверяем, если есть в этой группе данные по расстоянию 
        group_median = city_centers_rows['city_centers_nearest'].median() #высчитываем медиану для группы 
        data.loc[(data['locality_name'] == name) & (data['city_centers_nearest'].isna()), 'city_centers_nearest'] = group_median #заполняем медианой группы
        

data.loc[data['city_centers_nearest'].isna(), 'city_centers_nearest'] = data['city_centers_nearest'].median() # заполняем общей медианой все оставшиеся пропуски , применяя метод логической индексации

data['city_centers_nearest'].isna().sum()
# Out:
# 0

# %%
groups = data.groupby('locality_name')
for name, group in groups:
    parks_around3000_rows = group.query('parks_around3000 > 0')
    if len(parks_around3000_rows) > 0: #проверяем, если есть в этой группе данные по расстоянию 
        group_median = parks_around3000_rows['parks_around3000'].median() #высчитываем медиану для группы 
        data.loc[(data['locality_name'] == name) & (data['parks_around3000'].isna()), 'parks_around3000'] = group_median #заполняем медианой группы
        

data.loc[data['parks_around3000'].isna(), 'parks_around3000'] = data['parks_around3000'].median() # заполняем общей медианой все оставшиеся пропуски , применяя метод логической индексации

data['parks_around3000'].isna().sum()
# Out:
# 0

# %%
groups = data.groupby('locality_name')
for name, group in groups:
    parks_nearest_rows = group.query('parks_nearest > 0')
    if len(parks_nearest_rows) > 0: #проверяем, если есть в этой группе данные по расстоянию 
        group_median = parks_nearest_rows['parks_nearest'].median() #высчитываем медиану для группы 
        data.loc[(data['locality_name'] == name) & (data['parks_nearest'].isna()), 'parks_nearest'] = group_median #заполняем медианой группы
        

data.loc[data['parks_nearest'].isna(), 'parks_nearest'] = data['parks_nearest'].median() # заполняем общей медианой все оставшиеся пропуски , применяя метод логической индексации

data['parks_nearest'].isna().sum()
# Out:
# 0

# %%
groups = data.groupby('locality_name')
for name, group in groups:
    ponds_around3000_rows = group.query('ponds_around3000 > 0')
    if len(ponds_around3000_rows) > 0: #проверяем, если есть в этой группе данные по расстоянию 
        group_median = ponds_around3000_rows['ponds_around3000'].median() #высчитываем медиану для группы 
        data.loc[(data['locality_name'] == name) & (data['ponds_around3000'].isna()), 'ponds_around3000'] = group_median #заполняем медианой группы
        

data.loc[data['ponds_around3000'].isna(), 'ponds_around3000'] = data['ponds_around3000'].median() # заполняем общей медианой все оставшиеся пропуски , применяя метод логической индексации

data['ponds_around3000'].isna().sum()
# Out:
# 0

# %%
groups = data.groupby('locality_name')
for name, group in groups:
    ponds_nearest_rows = group.query('ponds_nearest> 0')
    if len(ponds_nearest_rows) > 0: #проверяем, если есть в этой группе данные по расстоянию 
        group_median = ponds_nearest_rows['ponds_nearest'].median() #высчитываем медиану для группы 
        data.loc[(data['locality_name'] == name) & (data['ponds_nearest'].isna()), 'ponds_nearest'] = group_median #заполняем медианой группы
        

data.loc[data['ponds_nearest'].isna(), 'ponds_nearest'] = data['ponds_nearest'].median() # заполняем общей медианой все оставшиеся пропуски , применяя метод логической индексации

data['ponds_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# Данные по расстояниям заполнены, перейдем к колонке с площадью living_area. Здесь мы будем использовать тотже алгоритм, но с другими переменными. Группируем по количеству комнат, далее находим медиану для каждой группы и заполняем пропуски.

# %%
display(data['rooms'].value_counts()) #посмотрим на уникальные значения и количество их упоминаний

group_rooms = data.groupby('rooms') #группировка по комнатам
for rooms, group in group_rooms: 
    living_area_rows = group.query('living_area > 0') #найдем все строки, по необходимому критерию 
    if len(living_area_rows) > 0: #проверяем, если есть в этой группе данные по площади
        group_median = living_area_rows['living_area'].median() #высчитываем медиану для группы 
        data.loc[(data['rooms'] == rooms) & (data['living_area'].isna()), 'living_area'] = group_median #заполняем медианой группы
        
data['living_area'].isna().sum() #выводим результат с количеством пропусков после заполнения
# Out:
# 1     8004
# 2     7897
# 3     5779
# 4     1172
# 5      325
# 0      194
# 6      104
# 7       59
# 8       12
# 9        8
# 10       3
# 14       2
# 11       2
# 19       1
# 12       1
# 16       1
# 15       1
# Name: rooms, dtype: int64
# 0

# %% [markdown]
# С площадью для кухни будет немного сложнее, для начала посмотрим,  есть ли значения о площади кухни во всех группах rooms.

# %%
df = data.groupby('rooms')['kitchen_area'].value_counts() #делаем группировку 

display(df)
# Out:
# rooms  kitchen_area
# 1      10.0            557
#        9.0             430
#        6.0             412
#        8.0             407
#        11.0            336
#                       ...
# 14     16.6              1
#        25.9              1
# 15     100.0             1
# 16     13.0              1
# 19     27.6              1
# Name: kitchen_area, Length: 1913, dtype: int64

# %%
data.loc[(data['rooms'] == 0) & (data['kitchen_area'].isna())] = 0 #заполняем нулевым значением все пропуски где ноль комнат, скорее всего это студии и в них нет информации о площади кухни.

#Дальше воспользуемся уже знакомым нам алгоритмом.
group_rooms = data.groupby('rooms')
for rooms, group in group_rooms:
    kitchen_area_rows = group.query('kitchen_area > 0')
    if len(kitchen_area_rows) > 0: 
        group_median = kitchen_area_rows['kitchen_area'].median() 
        data.loc[(data['rooms'] == rooms) & (data['kitchen_area'].isna()), 'kitchen_area'] = group_median 
        
data['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# Теперь разберемся с колонкой days_exposition. Она содержит информацию о жизни объявления, сколько дней оно было размещено. Посмотрим на графике как распределены пропуски. А также значения из колонки first_day_exposition переведем в объекты datetime методом pd.to_datetime.

# %%
#print(data['first_day_exposition'].head())
data['first_day_exposition']= pd.to_datetime(data['first_day_exposition'])
print(data['first_day_exposition'].head())# выведем первые 5 значений для проверки
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2015-08-20
# 3   2015-07-24
# 4   2018-06-19
# Name: first_day_exposition, dtype: datetime64[ns]

# %% [markdown]
# Построим гистограмму с распределением пропущенных значений относительно даты размещения объявления.

# %%
data.query('days_exposition.isna()', engine = 'python')['first_day_exposition'].hist(bins = 20, figsize=(10, 5))
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# На графике видно,  что количество пропущенных значений увеличивается к 2019 году, скорее всего значения пропущены в объявлениях, которые еще активны, в данном случае пропуски можно оставить, так как нам не известно время жизни объявления.

# %% [markdown]
# Посмотрим есть ли дубликаты в таблице, если еcть, то удалим спользуя метод drop_duplicates()

# %%
data.duplicated().sum() #считаем количество строк - дубликатов
# Out:
# 193

# %%
data = data.drop_duplicates().reset_index(drop=True) # сохраняем в переменной data, очищенную от дубликатов таблицу с новой индексацией и удалением старой.
data.duplicated().sum() #  проверяем еще раз на количество дубликатов
# Out:
# 0

# %% [markdown]
# **Вывод**

# %% [markdown]
# В результате были обработаны все пропуски в данных, кроме колонки days_exposition. Выведем наш датасет после этапа обработки.

# %%
data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height             0
# floors_total               0
# living_area                0
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name              0
# airports_nearest           0
# city_centers_nearest       0
# parks_around3000           0
# parks_nearest              0
# ponds_around3000           0
# ponds_nearest              0
# days_exposition         3157
# dtype: int64

# %% [markdown]
#  ### Замена типа данных

# %% [markdown]
# На этом этапе переходим к замене типа данных. Выведем общую информацию о таблице.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23372 entries, 0 to 23371
# Data columns (total 22 columns):
# total_images            23372 non-null int64
# last_price              23372 non-null float64
# total_area              23372 non-null float64
# first_day_exposition    23372 non-null datetime64[ns]
# rooms                   23372 non-null int64
# ceiling_height          23372 non-null float64
# floors_total            23372 non-null float64
# living_area             23372 non-null float64
# floor                   23372 non-null int64
# is_apartment            23372 non-null object
# studio                  23372 non-null object
# open_plan               23372 non-null object
# kitchen_area            23372 non-null float64
# balcony                 23372 non-null float64
# locality_name           23372 non-null object
# airports_nearest        23372 non-null float64
# city_centers_nearest    23372 non-null float64
# parks_around3000        23372 non-null float64
# ...

# %% [markdown]
# Поменяем тип данных в следующих колонках floors_total, is_apartment, studio, open_plan, balcony и в колонке city_centers_nearest, другие колонки с расстояниями нас не интересуют. Также необходимо изменить тип данных в колонке days_exposition, но так как пропуски решено было не заполнять, то тип данных изменить не получится.

# %%
data['floors_total'] = data['floors_total'].apply(int)
data['is_apartment'] = data['is_apartment'].apply(bool)
data['studio'] = data['studio'].apply(bool)
data['open_plan'] = data['open_plan'].apply(bool)
data['balcony'] = data['balcony'].apply(int)
data['city_centers_nearest'] = data['city_centers_nearest'].apply(int)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23372 entries, 0 to 23371
# Data columns (total 22 columns):
# total_images            23372 non-null int64
# last_price              23372 non-null float64
# total_area              23372 non-null float64
# first_day_exposition    23372 non-null datetime64[ns]
# rooms                   23372 non-null int64
# ceiling_height          23372 non-null float64
# floors_total            23372 non-null int64
# living_area             23372 non-null float64
# floor                   23372 non-null int64
# is_apartment            23372 non-null bool
# studio                  23372 non-null bool
# open_plan               23372 non-null bool
# kitchen_area            23372 non-null float64
# balcony                 23372 non-null int64
# locality_name           23372 non-null object
# airports_nearest        23372 non-null float64
# city_centers_nearest    23372 non-null int64
# parks_around3000        23372 non-null float64
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# В том числе метод `fillna` и `astype` можно применять к нескольким столбцам одновременно.
#
# Если столбцов более 2–ух, то рекомендую применять цикл `for`.
#
# Пример:
#
# `df.astype({ "col1": "float64", "col2": "int64"})`
#
# </div>

# %% [markdown]
# ```python
#
# columns = [col1, col2, col3]
#
# for i in columns:
#     df[i] = df[i].fillna(0)
#
# ```

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# На этом этапе необходимо посчитать и добавить в таблицу следующие параметры:
# - цену квадратного метра
# - день недели, месяц и год публикации объявления
# - этаж квартиры; варианты — первый, последний, другой
# - соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %% [markdown]
# Определим цену квадратного метра, для этого найдем отнешение last_price к total_area.

# %%
data['price_m2'] = data['last_price']/data['total_area']
print(data['price_m2'].head(10)) #посмотрим на результат.
# Out:
# 0    120370.370370
# 1     82920.792079
# 2     92785.714286
# 3    408176.100629
# 4    100000.000000
# 5     95065.789474
# 6     99195.710456
# 7    110544.692737
# 8     87454.764777
# 9     88524.590164
# Name: price_m2, dtype: float64

# %% [markdown]
# Добавим три столбца со значениями день недели, месяц и год публикации.

# %%
data['weekday_exposition'] = data['first_day_exposition'].dt.weekday
data['month_exposition'] = data['first_day_exposition'].dt.month
data['year_exposition'] = data['first_day_exposition'].dt.year

print(data['weekday_exposition'].head())#проверяем результаты 
print()
print(data['month_exposition'].head())
print()
print(data['year_exposition'].head())
# Out:
# 0    3
# 1    1
# 2    3
# 3    4
# 4    1
# Name: weekday_exposition, dtype: int64
#
# 0     3
# 1    12
# 2     8
# 3     7
# 4     6
# Name: month_exposition, dtype: int64
#
# 0    2019
# 1    2018
# 2    2015
# 3    2015
# 4    2018
# Name: year_exposition, dtype: int64

# %% [markdown]
# Добавим столбец с этажами квартир, у нас будет три категории - первый, последний, другой. Для начала посмотрим какие макс и мин значения в колонке floor. Затем напишем функцию классификации.

# %%
print(data['floor'].min())

print(data['floor'].max())
# Out:
# 0
# 33

# %% [markdown]
# Нулевой этаж, не особо реалистично для России, нумерация этажей начинается обычно с 1-го. Выведем строки с нулевым этажем.

# %%
display(data.query('floor == 0'))
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 144             0         0.0         0.0           1970-01-01      0
#
#      ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 144             0.0             0          0.0      0         False  ...
#
#      city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 144                     0               0.0            0.0               0.0
#
#     ponds_nearest  days_exposition  price_m2  weekday_exposition  \
# 144           0.0              0.0       NaN                   3
#
#      month_exposition  year_exposition
# 144                 1             1970
#
# [1 rows x 26 columns]

# %% [markdown]
# Всего одна строка, которая не удалилась, при обработке дубликатов, так как не является полностью явным дубликатом. Избавимся от нее

# %%
data = data.query('floor > 0') #сделаем срез через query и сохраним в нашем фрейме
print(data['floor'].min()) #проверяем результат
# Out:
# 1

# %%
def floor_group(floor): #функцию классификации применяем к столбцу 'floor'
     
    if floor <= 1 :
        return 'первый'
    if floor > 1 and floor <= 32:
        return 'другой'
    return 'последний'

print(floor_group(1)) #проверяем работу 
print(floor_group(5))
print(floor_group(33))
print()
data['floor_group'] = data['floor'].apply(floor_group) #создаем колонку с группами 


print(data['floor_group'].head())
# Out:
# первый
# другой
# последний
#
# 0    другой
# 1    первый
# 2    другой
# 3    другой
# 4    другой
# Name: floor_group, dtype: object

# %% [markdown]
# Определим соотношение жилой и общей площади, а также отношение площади кухни к общей.

# %%
data['ratio_area'] = data['living_area']/data['total_area']
data['ratio_kitchen_area'] = data['kitchen_area']/data['total_area']

display(data) #выведем общую таблицу после преобразований
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23367             9   9700000.0      133.81           2017-03-21      3
# 23368            14   3100000.0       59.00           2018-01-15      3
# 23369            18   2500000.0       56.70           2018-02-11      2
# 23370            13  11475000.0       76.75           2017-03-28      2
# 23371             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# **Вывод**

# %% [markdown]
# Итак после преобразований в нашей таблице появились целых 7 новых колонок, которые будут нам нужны для исследования.
# Взглянем на сводную инфу о таблице

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23371 entries, 0 to 23371
# Data columns (total 29 columns):
# total_images            23371 non-null int64
# last_price              23371 non-null float64
# total_area              23371 non-null float64
# first_day_exposition    23371 non-null datetime64[ns]
# rooms                   23371 non-null int64
# ceiling_height          23371 non-null float64
# floors_total            23371 non-null int64
# living_area             23371 non-null float64
# floor                   23371 non-null int64
# is_apartment            23371 non-null bool
# studio                  23371 non-null bool
# open_plan               23371 non-null bool
# kitchen_area            23371 non-null float64
# balcony                 23371 non-null int64
# locality_name           23371 non-null object
# airports_nearest        23371 non-null float64
# city_centers_nearest    23371 non-null int64
# parks_around3000        23371 non-null float64
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Мы достаточно детально обработали наши данные и добавили все необходимые значения в нашу выборку. Давай теперь проведём анализ.
#
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# **4.1** В этом разделе мы проведем исследовательский анализ данных, начнем с изучения параметров, таких как  площадь, цена, число комнат, высота потолков и время продажи квартиры. Построим гистограмму для каждого параметра.

# %%
data['total_area'].hist(bins=100 , range=(0,500), figsize=(12,6))

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# Не забывай пожалуйста подписавать каждый график. Это важный момент всего проект, потому что так быстрее понять о чем идёт речь на графике.
#
# </div>

# %%
data['total_area'].hist(bins=100 , range=(0,200), figsize=(12,6))

# %% [markdown]
# Исходя из этих гистограмм по площади можно сдлеать вывод, что у нас однозначно есть выбивающие значения или попрасту выбросы свыше 500 метров, а также до 20 метров, пик значений от 25 до 50 метров, далее гистограмма идет на спад, квартир на продажу с площадью от 50 до 100 метров значительно меньше, есть небольшое количество свыше 150 метров.
#
# Выведем числовое описание данных для большей информативности.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Чтобы нам в ручную не задавать параметр `range` мы можем посмотреть в открытом доступе  – как считать интерквартильный размах для нижнего и верхнего уровня нормального распределения.
#
# https://stackoverflow.com/questions/50461349/how-to-remove-outlier-from-dataframe-using-iqr
#
# </div>

# %%
data['total_area'].describe()
# Out:
# count    23371.000000
# mean        60.580161
# std         35.613640
# min         12.000000
# 25%         40.200000
# 50%         52.000000
# 75%         70.000000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Из описания можно сделать вывод, что средний размер квартир на продажу это 60 метров, основная часть квартир лежит в диапозоне от 40 до 70 метров, максимальный размер 900 м, что в принципе неправдаподобно, нулевые значения площади тоже присутсвуют в данных, значит следующим этапом избавимся от аномально больших и маленьких значений.

# %% [markdown]
# Построим диаграмму размаха и посмотрим на выбросы.

# %%
data.boxplot('total_area', figsize=(12,6)) 
plt.ylim(-20, 200)
# Out:
# (-20, 200)

# %% [markdown]
# Исходя из диаграммы выбросы начинаются после отметки 120 метров. Еще раз взглянем на нашу гистограмму- значения справа от пика начинают приближаются к нулю на отметке 175 метров, есть одиночные значения около 200, будет целесообразно искать верхнюю  и нижнюю границы  через перцинтиль, так как распределение у нас несимметричные.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Кстати для того чтобы подписать график мы можем использовать метод `plt.title()` и в конце кода применить `plt.show()`
# </div>

# %%
display(data['total_area'].quantile(0.99))

display(data['total_area'].quantile(0.1))
# Out:
# 197.92999999999992
# 33.0

# %% [markdown]
# Верхняя граница 198 метров, нижняя 33 метра.

# %%
df = data[(data['total_area'] > 33) & (data['total_area'] < 198)] #делаем срез строк и сохраняем в новом датафрейме
df['total_area'].head(20)
# Out:
# 0     108.00
# 1      40.40
# 2      56.00
# 3     159.00
# 4     100.00
# 6      37.30
# 7      71.60
# 8      33.16
# 9      61.00
# 10     39.60
# 11     44.00
# 12     54.00
# 13     42.80
# 14     36.00
# 15     39.00
# 16     82.00
# 17     36.00
# 19    121.00
# 20     80.00
# 22     58.00
# Name: total_area, dtype: float64

# %% [markdown]
# Теперь выведем информацию о стоимости квартир и построим гистограмму.

# %%
df['last_price'].describe()
# Out:
# count    2.078200e+04
# mean     6.395648e+06
# std      6.484879e+06
# min      1.219000e+04
# 25%      3.700000e+06
# 50%      4.900000e+06
# 75%      7.000000e+06
# max      3.300000e+08
# Name: last_price, dtype: float64

# %%
(df['last_price']/1000).hist(bins=20, range=(0,200000), figsize=(12,6)) #чтобы график был читаемый переведем цену в тысячи

# %%
(df['last_price']/1000).hist(bins=200, range=(0,50000), figsize=(12,6)) #поменяем диапозон значений в параметре range=(0,50000)

# %% [markdown]
# Какие выводы можно сделать - пиковые значения находятся на уровне около 5 млн руб. В объявлениях большенство квартир на продажу стоимостью до 10 млн. руб, максимальная стоимость 330 млн руб.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Обрати внимание, что наши действия повторяются с точки зрения построения графиков.
#
# Это говорит о том, что мы можем создать функцию, которая будет выполнять все действия за нас.
#
# Тем самым мы сможем оптимизировать свой код и проект целиком.
#
# </div>

# %% [markdown]
# Построим диаграмму размаха и посмотрим на выбросы.

# %%
lp =df['last_price']/1000 # разделим на 1000, чтобы наша диаграмма была читаемой
lp.plot.box(figsize=(12,6)) #зададим размер таблицы
plt.ylim(-2000, 20000) #зададим масштаб по вертикальной оси
# Out:
# (-2000, 20000)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здорово, что смотришь на данные разными графиками. Таким образом мы лучше изучаем данные.
#
# </div>

# %% [markdown]
# Выбросы находятся за пределами 12 млн.руб для точности опять же определим границы через перцинтиль.

# %%
display(df['last_price'].quantile(0.99))

display(df['last_price'].quantile(0.1))
# Out:
# 29000000.0
# 2700000.0

# %% [markdown]
# Верхняя граница будет на отметке 29 000 000 млн руб, за нижнюю границу примем значение 2 700 000 млн. руб.
# Сделаем срез и сохраним  в томже дата сете df. Затем перейдем к рассмотрению колонки с количеством комнат.

# %%
df = df[(df['last_price'] > 2700000.0) & (df['last_price'] < 29000000.0)]

# %% [markdown]
# Посмотрим на данные в колонке price_m2

# %%
(df['price_m2']/1000).hist(bins=200, range=(0,500), figsize=(12,6))

# %% [markdown]
# Пики на уровне 100 тыс руб за кв.метр

# %%
df['price_m2'].describe()
# Out:
# count     18482.000000
# mean     102077.922978
# std       31969.244499
# min       16842.105263
# 25%       81997.326203
# 50%       97222.222222
# 75%      116184.107143
# max      640422.350472
# Name: price_m2, dtype: float64

# %%
lp =df['price_m2']/1000 # разделим на 1000, чтобы наша диаграмма была читаемой
lp.plot.box(figsize=(12,6)) #зададим размер таблицы
plt.ylim(-20, 200) #зададим масштаб по вертикальной оси
# Out:
# (-20, 200)

# %%
display(df['price_m2'].quantile(0.99)) 

display(df['price_m2'].quantile(0.1))
# Out:
# 211474.2949926667
# 68628.9804533358

# %%
df = df[(df['price_m2'] > 68629) & (df['price_m2'] < 211474)] #делаем срез, на основании точных данных из расчетов перцинтилей.
display(df.head())
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 4             2  10000000.0       100.0           2018-06-19      2
# 6             6   3700000.0        37.3           2017-11-02      1
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70            16         51.0      8         False  ...
# 1            2.65            11         18.6      1         False  ...
# 2            2.65             5         34.3      4         False  ...
# 4            3.03            14         32.0     13         False  ...
# 6            2.65            26         10.6      6         False  ...
#
#    ponds_around3000  ponds_nearest  days_exposition       price_m2  \
# ...

# %%
df['rooms'].hist(figsize=(12,6)) #выводим гистограмму для rooms

# %%
df['rooms'].describe()
# Out:
# count    16448.000000
# mean         2.136552
# std          0.974825
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         11.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Исходя из гистограммы и описания методом describe() преобладающее число квартир- это двухкомнатные. Еще можно заметить, что макс количество комнат 11, это аномальное значение, так как данные частично заполнены клиентами, в данных может быть много неточностей и ошибочных значений. Посмотрим, что будет на диаграмме размаха .

# %%
df.boxplot('rooms', figsize=(12,6)) 
plt.ylim(0, 11)
# Out:
# (0, 11)

# %% [markdown]
# Из диаграммы видно, что верхний ус лежит на отметке 6, поэтому срез будем делать от 1 до 5.

# %%
df = df[df['rooms'] < 6]
df['rooms'].head(10)
# Out:
# 0     3
# 1     1
# 2     2
# 4     2
# 6     1
# 7     2
# 8     1
# 9     3
# 10    1
# 11    2
# Name: rooms, dtype: int64

# %% [markdown]
# Перейдем к исследованию высоты потолков. Посмотрим на гистограмму

# %%
df['ceiling_height'].hist(bins=10, range=(0,20),figsize=(12,6))

# %%
df['ceiling_height'].describe()
# Out:
# count    16376.000000
# mean         2.727888
# std          0.676881
# min          1.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.740000
# max         32.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# По гистограмме и описанию относительно средней высоты потолка можно сказать, что она на стандартном уровне - 2.6 метра, есть конечно и аномальные значения , избавимся от них.

# %%
df.boxplot('ceiling_height', figsize=(12,6)) 
plt.ylim(0, 4)
# Out:
# (0, 4)

# %%
display(df['ceiling_height'].quantile(0.99)) #Определим границы среза через перцинтиль, так будет точнее

display(df['ceiling_height'].quantile(0.1))
# Out:
# 3.6
# 2.5

# %%
df = df[(df['ceiling_height'] > 2.5) & (df['ceiling_height'] < 3.6)]

# %% [markdown]
# Выведем информацию по новой таблице.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14142 entries, 0 to 23370
# Data columns (total 29 columns):
# total_images            14142 non-null int64
# last_price              14142 non-null float64
# total_area              14142 non-null float64
# first_day_exposition    14142 non-null datetime64[ns]
# rooms                   14142 non-null int64
# ceiling_height          14142 non-null float64
# floors_total            14142 non-null int64
# living_area             14142 non-null float64
# floor                   14142 non-null int64
# is_apartment            14142 non-null bool
# studio                  14142 non-null bool
# open_plan               14142 non-null bool
# kitchen_area            14142 non-null float64
# balcony                 14142 non-null int64
# locality_name           14142 non-null object
# airports_nearest        14142 non-null float64
# city_centers_nearest    14142 non-null int64
# parks_around3000        14142 non-null float64
# ...

# %% [markdown]
# **4.2** Далее изучим время продажи квартиры. Построим гистограмму. Посчитаем среднее и медиану. Опишем, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?
# Обратимся к колонке days_exposition.

# %%
df_closed = df[~df['days_exposition'].isna()] # т.к пропуски мы не заполняли на этапе предобработки, то нам необходимо оставить строки только с данными
print(df_closed['days_exposition'].isna().sum()) # проверяем количество пропусков.
# Out:
# 0

# %%
df_closed['days_exposition'].hist(bins=100 , range=(0,1500), figsize=(12,6)) #строим гистограмму

plt.show()

df_closed['days_exposition'].hist(bins=100 , range=(0, 800), figsize=(12,6)) #изменим интервал, для наглядности

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Если вдруг тебе понравилась тема визуализации, рекомендую посмотреть на библиотеку `seaborn`
# </div>

# %%
df_closed['days_exposition'].describe()
# Out:
# count    12362.000000
# mean       183.108963
# std        222.357801
# min          2.000000
# 25%         45.000000
# 50%         97.000000
# 75%        232.000000
# max       1553.000000
# Name: days_exposition, dtype: float64

# %%
df.boxplot('days_exposition', figsize=(12,6)) 
plt.ylim(-10, 700)
# Out:
# (-10, 700)

# %% [markdown]
# И так будем делать вывод на основании всех выше выведенных графиков и описания. Наше среднее отличается от медианы почти в два раза ,судя по графику в распределении большой хвост с высокими значениями.
# медиана на отметке 99, среднее 185. Обычно продажи занимают от 45 дней до 238 дней, на второй гистограмме это можно увидеть, пиковые значения как раз находятся в этом диапазоне, всё что находится в пределах усов -  нормальные значения. Продажи до 45 дней считаются быстрыми, всё что свыше отметки 238 - можно определить как долгие продажи.
# Теперь отбросим все аномалии и редкие значения. Определим нижнюю и верхнюю границу. На основании нашей диаграммы, мы должны исключить все значения свыше 520 дней, но мне кажется мы лишимся большого количества значений, так как после отметки в 600 и в 1000 значения еще не сходятся к нулю, есть небольшие скачки. Поэтому лучшим решением будет определить границы через перцинтиль.

# %%
display(df_closed['days_exposition'].quantile(0.99)) #Определим границы среза через перцинтиль, так будет точнее

display(df_closed['days_exposition'].quantile(0.1))
# Out:
# 1077.3899999999994
# 17.0

# %%
df_closed= df_closed[(df_closed['days_exposition'] > 17) & (df_closed['days_exposition'] < 1077)]
df_closed['days_exposition'].describe()
# Out:
# count    10961.000000
# mean       191.260286
# std        198.506852
# min         18.000000
# 25%         59.000000
# 50%        114.000000
# 75%        252.000000
# max       1076.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# **Вывод**

# %% [markdown]
# И так все аномалии и выбивающие значения на этих двух этапах мы удалили, в процессе исследования было обнаружено не мало аномальных значений во всех колонках, особенно в пункте 4.1 , так как эти данные заполняют сами пользователи, то обнаружить странные цыфры - не удивительно, людям свойственно ошибаться.
# На этом исследование не заканчивается, дальше мы рассмотрим факторы влияния на стоимость.

# %% [markdown]
# **4.3**
# В этом пункте мы определим: какие факторы больше всего влияют на стоимость квартиры. Изучим, зависит ли цена от площади, числа комнат, удалённости от центра. Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучим зависимость от даты размещения: дня недели, месяца и года.
# Взаимосвязь будем определять через корреляцию, находить коэффициент корреляции Пирсона.

# %%
# так как действия однотипные лучше всего пробежаться циклом
# создадим список значений, для которых будем выводить корреляцию с price_m².

list_corr = ['total_area', 'rooms', 'city_centers_nearest']

for column in list_corr:
    print("Корреляция между " + "price_m2" + " and " + column)
    print(df['price_m2'].corr(df[column]))
    df.plot(x=column, y='price_m2', kind='hexbin', gridsize=20, figsize=(8, 6), sharex=False, grid=True) 
    plt.show()
# Out:
# Корреляция между price_m2 and total_area
# 0.15126291409127648
# Корреляция между price_m2 and rooms
# -0.07897677409732191
# Корреляция между price_m2 and city_centers_nearest
# -0.3143986108441291

# %% [markdown]
# Можно сделать вывод, хоть корреляция во всех трех случаях иллюстрирует зависимость между величинами , линейной эту взаимосвязь назвать точно нельзя, так как коэффициент Пирсона близок к нулю. Рассмотрим боллее детально каждый фактор, посмотрим какие выводы можно бует сделать.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здорово, что получилось применить автоматизацию построения графиков 👍
#
# Теперь в нужный момент мы сможем применить данный инструмент.
#
# </div>

# %% [markdown]
# Рассмотрим расстоние до центра

# %%
df['city_centers_nearest_km'] = (df['city_centers_nearest']/1000).astype(int) # создадим колонку с целочисленным значением.

df_price_km = df.pivot_table(index = 'city_centers_nearest_km' , values = 'price_m2', aggfunc = 'median').round() #находим медианную цену за кв.метр 
display(df_price_km)
df_price_km.plot(style='o-', grid=True, figsize=(15, 5), xlim=(0, 100))
# Out:
#                          price_m2
# city_centers_nearest_km
# 0                        116774.0
# 1                        115922.0
# 2                        109658.0
# 3                        105673.0
# 4                        122087.0
# 5                        120656.0
# 6                        123201.0
# 7                        123958.0
# 8                        116866.0
# 9                        105566.0
# 10                       106893.0
# 11                       102811.0
# 12                       104856.0
# 13                        91799.0
# 14                       103789.0
# 15                       100000.0
# 16                        99748.0
# 17                        94842.0
# 18                        95503.0
# 19                        93220.0
# 20                       103439.0
# 21                        88235.0
# 22                        85690.0
# 23                        81619.0
# 24                        86522.0
# 25                        89303.0
# ...

# %% [markdown]
# Исходя из графика, можно сделать вывод, что самая высокая цена за кв.метр ближе к центру, чем дальше тем дешевле, но в отметке 40 км происодит резкое падение и скачек.

# %%
#рассматриваем зависимость цены за кв.м от площади.
df_price_area = df.pivot_table(index = 'total_area' , values = 'price_m2', aggfunc = 'median').round() #находим медианную цену за кв.метр 
display(df_price_area)
df_price_area.plot(style='o-', grid=True, figsize=(15, 5), xlim=(30, 100))
# Out:
#             price_m2
# total_area
# 33.02       135373.0
# 33.07        93007.0
# 33.09        93004.0
# 33.10       110272.0
# 33.16        87455.0
# ...              ...
# 188.00      148936.0
# 190.00      113947.0
# 192.10       93701.0
# 196.00      101531.0
# 197.00       97462.0
#
# [1535 rows x 1 columns]

# %% [markdown]
# В целом цена не зависит от площади.

# %%
#рассматриваем зависимость цены за кв.м от количества комнат.

df_price_rooms = df.pivot_table(index = 'rooms' , values = 'price_m2', aggfunc = 'median').round() #находим медианную цену за кв.метр 
display(df_price_rooms)
df_price_rooms.plot(kind='bar' ,figsize=(15, 5))
# Out:
#        price_m2
# rooms
# 1      105618.0
# 2      100419.0
# 3       96369.0
# 4       98214.0
# 5       95000.0

# %% [markdown]
# Как мы видим цена за кв.м  однокомнатной квартиры выше, такие квартиры более востребованы на рынке недвижимости.

# %%
list_corr = ['weekday_exposition', 'month_exposition','year_exposition']

for column in list_corr:
    print("Корреляция между " + "price_m2" + " and " + column)
    print(df['price_m2'].corr(df[column]))
    df.plot(x=column, y='price_m2', kind='hexbin', gridsize=20, figsize=(8, 6), sharex=False, grid=True) 
    plt.show()
# Out:
# Корреляция между price_m2 and weekday_exposition
# -0.0112469963110756
# Корреляция между price_m2 and month_exposition
# -0.00747461097893355
# Корреляция между price_m2 and year_exposition
# 0.07772153673938834

# %% [markdown]
# И так, прямая взаимосвязь между ценой за кв.метр  днем недели, месяцем и годом тоже отсутствует. Здесь бы хотелось отдельно выделить на рассмотрение только год.

# %%
df_price_years = df.pivot_table(index = 'year_exposition' , values = 'price_m2', aggfunc = 'median').round() #находим медианную цену за кв.метр 
display(df_price_years)
df_price_years.plot(kind='bar' ,figsize=(15, 5))
# Out:
#                  price_m2
# year_exposition
# 2014             120360.0
# 2015              98077.0
# 2016              97341.0
# 2017              98888.0
# 2018             102041.0
# 2019             108824.0

# %% [markdown]
# Цена кв.метра была самой пиковой в 2014 году, это было как раз докризисное время.

# %%
# этажи выведены в отдельную группу и относятся к категориальному типу переменных, провести корреляцию мы не сможем, рассмотрим взаимосвязь через boxplot.
df.boxplot(column = 'price_m2', by = 'floor_group',figsize=(12,6))
plt.ylim(1, 250000)
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# (1, 250000)

# %% [markdown]
# По диаграмме можно утверждать, что стоимость кв.метра на первом этаже ниже чем на других, это не удивительно.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Кстати можно отключить предупреждения с помощью следующего способа ниже.
#
# `import warnings`
#
# `warnings.simplefilter('ignore')`
#
# </div>

# %% [markdown]
# **4.4** Определим 10 населённых пунктов с наибольшим числом объявлений. Посчитаем среднюю цену квадратного метра в этих населённых пунктах. Выделим населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %%
#выведем 10 нас.пунктов с наибольшим числом объявлений и сохраним в переменную
top_locality = df['locality_name'].value_counts().head(10).index
top_locality
# Out:
# Index(['Санкт-Петербург', 'Кудрово', 'Мурино', 'Парголово', 'Пушкин', 'Шушары',
#        'Колпино', 'Сестрорецк', 'Всеволожск', 'Петергоф'],
#       dtype='object')

# %%
#определим среднюю цену кв.метра price_m2
df[df['locality_name'].isin(top_locality)].groupby('locality_name').agg({'price_m2': 'mean'})
# Out:
#                       price_m2
# locality_name
# Всеволожск        79995.691829
# Колпино           79682.792122
# Кудрово           94313.175701
# Мурино            87586.259049
# Парголово         94151.431022
# Петергоф          87673.476425
# Пушкин           104816.449804
# Санкт-Петербург  110589.551698
# Сестрорецк       105283.622313
# Шушары            83040.418034

# %% [markdown]
# **Вывод**

# %% [markdown]
# Исходя из приведенных данных, можно сказать, что в Санкт-Петербурге, Пушкине, Сестрорецке самая высокая стоимость жилья, а самая низкая в Всеволожске, Гатчине, Колпино.

# %% [markdown]
# **4.5**
# Изучим предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделим квартиры в Санкт-Петербурге (locality_name). Наша задача — выяснить, какая область входит в центр. Создать столбец с расстоянием до центра в километрах: округлить до целых значений. После этого посчитать среднюю цену для каждого километра. Построить график: он должен показывать, как цена зависит от удалённости от центра. Определить границу, где график сильно меняется, — это и будет центральная зона.

# %%
#выделим квартиры в Санкт-Петербурге
spb_apartment = df.query('locality_name == "Санкт-Петербург"')

# сделаем сводную таблицу, где индексом будет расстояние в км. а по цене будем считать среднее.
df_spb_price = spb_apartment.pivot_table(index = 'city_centers_nearest_km' , values = 'price_m2', aggfunc = 'mean').round()
display(df_spb_price)
# Out:
#                          price_m2
# city_centers_nearest_km
# 0                        122309.0
# 1                        121329.0
# 2                        114853.0
# 3                        114224.0
# 4                        125320.0
# 5                        125328.0
# 6                        126810.0
# 7                        124982.0
# 8                        119998.0
# 9                        110667.0
# 10                       112026.0
# 11                       106498.0
# 12                       109610.0
# 13                       107798.0
# 14                       106188.0
# 15                       104259.0
# 16                       101670.0
# 17                        98762.0
# 18                       101761.0
# 19                        96672.0
# 20                       107870.0
# 21                        93059.0
# 22                        90437.0
# 23                        90167.0
# 24                        87699.0
# 25                        89990.0
# ...

# %%
#строим график зависимости цены от от удаленности от центра.
    
df_spb_price.plot( kind='bar', label='index', figsize = (15,3))

# %% [markdown]
# **Вывод**

# %% [markdown]
# Можно сделать вывод, что центральная зона ограничевается расстоянием в 8км.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Ориентировочно да, потому что дальше идёт в том числе спад и длительная стагнация стоимости.
#
# </div>

# %% [markdown]
# **4.6** Выделим сегмент квартир в центре. Проанализируем эту территорию и изучим следующие параметры: площадь, цена, число комнат, высота потолков. Также необходимо выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделать выводы. Отличаются ли они от общих выводов по всему городу?

# %%
#выделим сегмент квартир в центре, всё что в пределах 8км. 
central_zone = df.query('city_centers_nearest_km <= 8')
display(central_zone.head(10))
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 4               2  10000000.0       100.0           2018-06-19      2
# 35              6  15500000.0       149.0           2017-06-26      5
# 61             18   7990000.0        74.0           2017-08-24      2
# 63              2  20000000.0       118.0           2018-09-11      3
# 98             11  11700000.0        80.0           2014-12-10      3
# 99             32   9600000.0        90.0           2017-09-26      4
# 106             9  10500000.0       124.1           2017-05-25      5
# 111             4   4590000.0        40.0           2017-05-29      1
# 115             8   3850000.0        42.0           2018-11-05      2
# 136            16   6500000.0        51.8           2018-08-01      2
#
#      ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 4              3.03            14         32.0     13         False  ...
# ...

# %%
#Посмотрим влияние факторов (число комнат, этаж, удалённость от центра, дата размещения объявления) на стоимость квартиры. 

list_corr = ['rooms', 'city_centers_nearest']

for column in list_corr:
    print("Корреляция между " + "price_m2" + " and " + column)
    print(central_zone['price_m2'].corr(central_zone[column]))
# Out:
# Корреляция между price_m2 and rooms
# -0.3046082952796219
# Корреляция между price_m2 and city_centers_nearest
# 0.04335767992609796

# %% [markdown]
# Коэффициент Пирсона ниже нуля и соответственно линейной зависимости нет, рассмотрим более детально каждый из факторов и здесь же будем проводить сравнение с предыдущими выводами по всему городу.

# %%
#рассматриваем зависимость цены за кв.м от количества комнат.
central_zone_price_rooms = central_zone.pivot_table(index = 'rooms' , values = 'price_m2', aggfunc = 'median').round()
central_zone_price_rooms.plot(kind='bar' ,figsize=(15, 5), title = 'Центр города')
display(central_zone_price_rooms)
plt.show()
df_price_rooms.plot(kind='bar' ,figsize=(15, 5), title = 'Весь город')
# Out:
#        price_m2
# rooms
# 1      139120.0
# 2      121262.0
# 3      111111.0
# 4      103434.0
# 5       94118.0

# %% [markdown]
# В центре города , однокомнатные квартиры более востребованы, их в целом больше чем 3х , 4х и 5ти-комнатных, соответственно и цена выше. Если сравнивать с выводами по всему городу, то цена за кв.метр практически на одном уровне лишь в 5ти-комнатных квартирах, цена за кв.метр однушки или двушки достаточно выше.

# %%
#рассматриваем зависимость цены за кв.м от расстояния
central_zone_price_km = central_zone.pivot_table(index = 'city_centers_nearest_km' , values = 'price_m2', aggfunc = 'median').round() #находим медианную цену за кв.метр 
display(central_zone_price_km)
central_zone_price_km.plot(style='o-', grid=True, figsize=(15, 5), title = 'Центр города')
plt.show()
df_price_km.plot(style='o-', grid=True, figsize=(15, 5), title = 'Весь город')
# Out:
#                          price_m2
# city_centers_nearest_km
# 0                        116774.0
# 1                        115922.0
# 2                        109658.0
# 3                        105673.0
# 4                        122087.0
# 5                        120656.0
# 6                        123201.0
# 7                        123958.0
# 8                        116866.0

# %% [markdown]
# Вывод достаточно логичный, чем меньше расстояние к центру - тем дороже кв.метр недвижимости. Но на нашем графике "центр города" видно, что в отметке 3км цена резко падает, это так называемый "Питерский серый пояс", после него цена снова начинает стремительно расти.

# %%
#влияние этажа на стоимость посмотрим через boxplot
ax1 = central_zone.boxplot(column = 'price_m2', by = 'floor_group',figsize=(10,5))
plt.ylim(1, 250000)
ax1.set_title('Центр города')

plt.show()
ax2 = df.boxplot(column = 'price_m2', by = 'floor_group',figsize=(10,5))
plt.ylim(1, 250000)

ax2.set_title('Весь город')
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 1.0, 'Весь город')

# %% [markdown]
# Из выше приведенных диаграмм можно сказать , что ни в центре ни в других районах города квартиры на первых этажах популярностью не пользуются. медианная цена за кв.метр на первом этаже в центре не намного выше чем по всему городу. На других этажах различия в цене становятся более явными.

# %%
list_corr = ['weekday_exposition', 'month_exposition','year_exposition']

for column in list_corr:
    print("Корреляция между " + "price_m2" + " and " + column)
    print(central_zone['price_m2'].corr(central_zone[column]))
# Out:
# Корреляция между price_m2 and weekday_exposition
# 0.006480607232316195
# Корреляция между price_m2 and month_exposition
# -0.019770057568970448
# Корреляция между price_m2 and year_exposition
# 0.07838645907757223

# %% [markdown]
# Линейной зависимости нет, посмотрим более детально на зависимость между годом и медианной ценой за кв.метр, более дтеально зависимости между ценой и месяцем или днем недели рассматривать не будем, врятли там будет заметна явная тенденция изменения цены.

# %%
central_zone_price_years = central_zone.pivot_table(index = 'year_exposition' , values = 'price_m2', aggfunc = 'median').round() #находим медианную цену за кв.метр 
central_zone_price_years .plot(kind='bar' ,figsize=(15, 5), title = 'Центр города')
display(central_zone_price_years)
plt.show()
df_price_years.plot(kind='bar' ,figsize=(15, 5), title = 'Весь город')
# Out:
#                  price_m2
# year_exposition
# 2014             128750.0
# 2015             115920.0
# 2016             113218.0
# 2017             116883.0
# 2018             118930.0
# 2019             126113.0

# %% [markdown]
# Как уже ранее было отмечено, что самая высокая медиан. стоимость кв.метра была в до кризисное время в 2014 году, потом цены пошли на спад и после 2016 года снова начали подниматься.
# Тенденции в графиках идентичны, отличается лишь цена кв.метра , в центре она как всегда выше.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Кстати можно было бы сравнить центр и весь город в целом, для наглядности наших расчетов.
#
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В заключении хотелось бы сказать, что была проведена большая работа в области анализа данных на основе архива объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Целью, которой было установление параметров, для построения автоматизированной системы, которая позволит отследить аномалии и мошенническую деятельность.
# В процессе работы, были замечены пропуски в данных и дубликаты, которые были обработаны с помощью различных методов, а также были удалены редкие и выбивающиеся значения, вся информация была подготовлена к дальшейшему исследованию.
# В процессе исследования были изучены факторы, которые могут оказать влияние на стоимость квартиры, такие как площадь, число комнат, этаж и дата размещения объявления, но никакой прямой зависимости между ценой и каким-либо из факторов выявлено не было.
# После более детального исследования между медианной ценой за кв.метр и вышеперечисленными факторами можно сделать вывод, что медианная цена за кв.метр в центре города выше чем по всему городу в целом, что достаточно логично. Наиболее высокая цена кв.метра была в 2014 году, цена кв.метра однокомнатной квартиры всегда выше, особенно это заметно в центре города.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# В целом сам проект выполнен на хорошем уровне! На протяжении всей работы чувствуется глубина проработки задачи и это безусловный плюс для нас. Было использовано большое количество методов, которые будут помогать тебе в дальнейших проектах.
#
#
# Поздравляю с успешным завершением проекта 😊👍
#
# И желаю успехов в новых работах 😊
#
# **[общий комментарий]** Ячейки **markdown** в том числе мы можем использовать как дополнительный способ стилизации нашего проекта. Оставил ниже ссылку, с примерами стилизации.
#
# https://sqlbak.com/blog/jupyter-notebook-markdown-cheatsheet
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [ ]  файлы изучены (выведены первые строки, метод info())
# - [ ]  определены пропущенные значения
# - [ ]  заполнены пропущенные значения
# - [ ]  есть пояснение, какие пропущенные значения обнаружены
# - [ ]  изменены типы данных
# - [ ]  есть пояснение, в каких столбцах изменены типы и почему
# - [ ]  посчитано и добавлено в таблицу: цена квадратного метра
# - [ ]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [ ]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [ ]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [ ]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [ ]  построены гистограммы для каждого параметра
# - [ ]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [ ]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [ ]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [ ]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [ ]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [ ]  в каждом этапе есть выводы
# - [ ]  есть общий вывод
