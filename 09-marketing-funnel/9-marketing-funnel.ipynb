# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1">Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2">Описание данных</a></span></li><li><span><a href="#Шаг-1.-Откройте-файл-с-данными-и-изучите-общую-информацию" data-toc-modified-id="Шаг-1.-Откройте-файл-с-данными-и-изучите-общую-информацию-3">Шаг 1. Откройте файл с данными и изучите общую информацию</a></span></li><li><span><a href="#Шаг-2.-Подготовьте-данные" data-toc-modified-id="Шаг-2.-Подготовьте-данные-4">Шаг 2. Подготовьте данные</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#2.1-Замените-названия-столбцов-на-удобные-для-вас" data-toc-modified-id="2.1-Замените-названия-столбцов-на-удобные-для-вас-4.0.1">2.1 Замените названия столбцов на удобные для вас</a></span></li><li><span><a href="#2.2-Проверьте-пропуски-и-типы-данных.-Откорректируйте,-если-нужно" data-toc-modified-id="2.2-Проверьте-пропуски-и-типы-данных.-Откорректируйте,-если-нужно-4.0.2">2.2 Проверьте пропуски и типы данных. Откорректируйте, если нужно</a></span></li><li><span><a href="#2.3-Добавьте-столбец-даты-и-времени,-а-также-отдельный-столбец-дат" data-toc-modified-id="2.3-Добавьте-столбец-даты-и-времени,-а-также-отдельный-столбец-дат-4.0.3">2.3 Добавьте столбец даты и времени, а также отдельный столбец дат</a></span></li></ul></li></ul></li><li><span><a href="#Шаг-3.-Изучите-и-проверьте-данные" data-toc-modified-id="Шаг-3.-Изучите-и-проверьте-данные-5">Шаг 3. Изучите и проверьте данные</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#3.1-Сколько-всего-событий-в-логе?" data-toc-modified-id="3.1-Сколько-всего-событий-в-логе?-5.0.1">3.1 Сколько всего событий в логе?</a></span></li><li><span><a href="#3.2-Сколько-всего-пользователей-в-логе?" data-toc-modified-id="3.2-Сколько-всего-пользователей-в-логе?-5.0.2">3.2 Сколько всего пользователей в логе?</a></span></li><li><span><a href="#3.3-Сколько-в-среднем-событий-приходится-на-пользователя?" data-toc-modified-id="3.3-Сколько-в-среднем-событий-приходится-на-пользователя?-5.0.3">3.3 Сколько в среднем событий приходится на пользователя?</a></span></li><li><span><a href="#3.4-Данными-за-какой-период-вы-располагаете?-Найдите-максимальную-и-минимальную-дату.-Постройте-гистограмму-по-дате-и-времени.--Можно-ли-быть-уверенным,-что-у-вас-одинаково-полные-данные-за-весь-период?-Технически-в-логи-новых-дней-по-некоторым-пользователям-могут-«доезжать»-события-из-прошлого-—-это-может-«перекашивать-данные».----Определите,-с-какого-момента-данные-полные-и-отбросьте-более-старые.-Данными-за-какой-период-времени-вы-располагаете-на-самом-деле?" data-toc-modified-id="3.4-Данными-за-какой-период-вы-располагаете?-Найдите-максимальную-и-минимальную-дату.-Постройте-гистограмму-по-дате-и-времени.--Можно-ли-быть-уверенным,-что-у-вас-одинаково-полные-данные-за-весь-период?-Технически-в-логи-новых-дней-по-некоторым-пользователям-могут-«доезжать»-события-из-прошлого-—-это-может-«перекашивать-данные».----Определите,-с-какого-момента-данные-полные-и-отбросьте-более-старые.-Данными-за-какой-период-времени-вы-располагаете-на-самом-деле?-5.0.4">3.4 Данными за какой период вы располагаете? Найдите максимальную и минимальную дату. Постройте гистограмму по дате и времени.  Можно ли быть уверенным, что у вас одинаково полные данные за весь период? Технически в логи новых дней по некоторым пользователям могут «доезжать» события из прошлого — это может «перекашивать данные».    Определите, с какого момента данные полные и отбросьте более старые. Данными за какой период времени вы располагаете на самом деле?</a></span></li><li><span><a href="#3.5-Много-ли-событий-и-пользователей-вы-потеряли,-отбросив-старые-данные?" data-toc-modified-id="3.5-Много-ли-событий-и-пользователей-вы-потеряли,-отбросив-старые-данные?-5.0.5">3.5 Много ли событий и пользователей вы потеряли, отбросив старые данные?</a></span></li><li><span><a href="#3.6-Проверьте,-что-у-вас-есть-пользователи-из-всех-трёх-экспериментальных-групп." data-toc-modified-id="3.6-Проверьте,-что-у-вас-есть-пользователи-из-всех-трёх-экспериментальных-групп.-5.0.6">3.6 Проверьте, что у вас есть пользователи из всех трёх экспериментальных групп.</a></span></li></ul></li></ul></li><li><span><a href="#Шаг-4.-Изучите-воронку-событий" data-toc-modified-id="Шаг-4.-Изучите-воронку-событий-6">Шаг 4. Изучите воронку событий</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#4.1-Посмотрите,-какие-события-есть-в-логах,-как-часто-они-встречаются.-Отсортируйте-события-по-частоте." data-toc-modified-id="4.1-Посмотрите,-какие-события-есть-в-логах,-как-часто-они-встречаются.-Отсортируйте-события-по-частоте.-6.0.1">4.1 Посмотрите, какие события есть в логах, как часто они встречаются. Отсортируйте события по частоте.</a></span></li><li><span><a href="#4.2-Посчитайте,-сколько-пользователей-совершали-каждое-из-этих-событий.-Отсортируйте-события-по-числу-пользователей.-Посчитайте-долю-пользователей,-которые-хоть-раз-совершали-событие." data-toc-modified-id="4.2-Посчитайте,-сколько-пользователей-совершали-каждое-из-этих-событий.-Отсортируйте-события-по-числу-пользователей.-Посчитайте-долю-пользователей,-которые-хоть-раз-совершали-событие.-6.0.2">4.2 Посчитайте, сколько пользователей совершали каждое из этих событий. Отсортируйте события по числу пользователей. Посчитайте долю пользователей, которые хоть раз совершали событие.</a></span></li><li><span><a href="#4.3-Предположите,-в-каком-порядке-происходят-события.-Все-ли-они-выстраиваются-в-последовательную-цепочку?-Их-не-нужно-учитывать-при-расчёте-воронки." data-toc-modified-id="4.3-Предположите,-в-каком-порядке-происходят-события.-Все-ли-они-выстраиваются-в-последовательную-цепочку?-Их-не-нужно-учитывать-при-расчёте-воронки.-6.0.3">4.3 Предположите, в каком порядке происходят события. Все ли они выстраиваются в последовательную цепочку? Их не нужно учитывать при расчёте воронки.</a></span></li><li><span><a href="#4.4-По-воронке-событий-посчитайте,-какая-доля-пользователей-проходит-на-следующий-шаг-воронки-(от-числа-пользователей-на-предыдущем).-То-есть-для-последовательности-событий-A-→-B-→-C-посчитайте-отношение-числа-пользователей-с-событием-B-к-количеству-пользователей-с-событием-A,-а-также-отношение-числа-пользователей-с-событием-C-к-количеству-пользователей-с-событием-B." data-toc-modified-id="4.4-По-воронке-событий-посчитайте,-какая-доля-пользователей-проходит-на-следующий-шаг-воронки-(от-числа-пользователей-на-предыдущем).-То-есть-для-последовательности-событий-A-→-B-→-C-посчитайте-отношение-числа-пользователей-с-событием-B-к-количеству-пользователей-с-событием-A,-а-также-отношение-числа-пользователей-с-событием-C-к-количеству-пользователей-с-событием-B.-6.0.4">4.4 По воронке событий посчитайте, какая доля пользователей проходит на следующий шаг воронки (от числа пользователей на предыдущем). То есть для последовательности событий A → B → C посчитайте отношение числа пользователей с событием B к количеству пользователей с событием A, а также отношение числа пользователей с событием C к количеству пользователей с событием B.</a></span></li><li><span><a href="#4.5-На-каком-шаге-теряете-больше-всего-пользователей?-Какая-доля-пользователей-доходит-от-первого-события-до-оплаты?" data-toc-modified-id="4.5-На-каком-шаге-теряете-больше-всего-пользователей?-Какая-доля-пользователей-доходит-от-первого-события-до-оплаты?-6.0.5">4.5 На каком шаге теряете больше всего пользователей? Какая доля пользователей доходит от первого события до оплаты?</a></span></li></ul></li></ul></li><li><span><a href="#Шаг-5.-Изучите-результаты-эксперимента" data-toc-modified-id="Шаг-5.-Изучите-результаты-эксперимента-7">Шаг 5. Изучите результаты эксперимента</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#5.1-Сколько-пользователей-в-каждой-экспериментальной-группе?" data-toc-modified-id="5.1-Сколько-пользователей-в-каждой-экспериментальной-группе?-7.0.1">5.1 Сколько пользователей в каждой экспериментальной группе?</a></span></li><li><span><a href="#5.2-Есть-2-контрольные-группы-для-А/А-эксперимента,-чтобы-проверить-корректность-всех-механизмов-и-расчётов.-Проверьте,-находят-ли-статистические-критерии-разницу-между-выборками-246-и-247." data-toc-modified-id="5.2-Есть-2-контрольные-группы-для-А/А-эксперимента,-чтобы-проверить-корректность-всех-механизмов-и-расчётов.-Проверьте,-находят-ли-статистические-критерии-разницу-между-выборками-246-и-247.-7.0.2">5.2 Есть 2 контрольные группы для А/А-эксперимента, чтобы проверить корректность всех механизмов и расчётов. Проверьте, находят ли статистические критерии разницу между выборками 246 и 247.</a></span></li><li><span><a href="#+" data-toc-modified-id="+-7.0.3">+</a></span></li><li><span><a href="#5.3-Выберите-самое-популярное-событие.-Посчитайте-число-пользователей,-совершивших-это-событие-в-каждой-из-контрольных-групп.-Посчитайте-долю-пользователей,-совершивших-это-событие.-Проверьте,-будет-ли-отличие-между-группами-статистически-достоверным.-Проделайте-то-же-самое-для-всех-других-событий-(удобно-обернуть-проверку-в-отдельную-функцию).-Можно-ли-сказать,-что-разбиение-на-группы-работает-корректно?" data-toc-modified-id="5.3-Выберите-самое-популярное-событие.-Посчитайте-число-пользователей,-совершивших-это-событие-в-каждой-из-контрольных-групп.-Посчитайте-долю-пользователей,-совершивших-это-событие.-Проверьте,-будет-ли-отличие-между-группами-статистически-достоверным.-Проделайте-то-же-самое-для-всех-других-событий-(удобно-обернуть-проверку-в-отдельную-функцию).-Можно-ли-сказать,-что-разбиение-на-группы-работает-корректно?-7.0.4">5.3 Выберите самое популярное событие. Посчитайте число пользователей, совершивших это событие в каждой из контрольных групп. Посчитайте долю пользователей, совершивших это событие. Проверьте, будет ли отличие между группами статистически достоверным. Проделайте то же самое для всех других событий (удобно обернуть проверку в отдельную функцию). Можно ли сказать, что разбиение на группы работает корректно?</a></span></li><li><span><a href="#5.4-Аналогично-поступите-с-группой-с-изменённым-шрифтом.-Сравните-результаты-с-каждой-из-контрольных-групп-в-отдельности-по-каждому-событию.-Сравните-результаты-с-объединённой-контрольной-группой.-Какие-выводы-из-эксперимента-можно-сделать?" data-toc-modified-id="5.4-Аналогично-поступите-с-группой-с-изменённым-шрифтом.-Сравните-результаты-с-каждой-из-контрольных-групп-в-отдельности-по-каждому-событию.-Сравните-результаты-с-объединённой-контрольной-группой.-Какие-выводы-из-эксперимента-можно-сделать?-7.0.5">5.4 Аналогично поступите с группой с изменённым шрифтом. Сравните результаты с каждой из контрольных групп в отдельности по каждому событию. Сравните результаты с объединённой контрольной группой. Какие выводы из эксперимента можно сделать?</a></span></li><li><span><a href="#5.5-Какой-уровень-значимости-вы-выбрали-при-проверке-статистических-гипотез-выше?-Посчитайте,-сколько-проверок-статистических-гипотез-вы-сделали.-При-уровне-значимости-0.1-каждый-десятый-раз-можно-получать-ложный-результат.-Какой-уровень-значимости-стоит-применить?-Если-вы-хотите-изменить-его,-проделайте-предыдущие-пункты-и-проверьте-свои-выводы." data-toc-modified-id="5.5-Какой-уровень-значимости-вы-выбрали-при-проверке-статистических-гипотез-выше?-Посчитайте,-сколько-проверок-статистических-гипотез-вы-сделали.-При-уровне-значимости-0.1-каждый-десятый-раз-можно-получать-ложный-результат.-Какой-уровень-значимости-стоит-применить?-Если-вы-хотите-изменить-его,-проделайте-предыдущие-пункты-и-проверьте-свои-выводы.-7.0.6">5.5 Какой уровень значимости вы выбрали при проверке статистических гипотез выше? Посчитайте, сколько проверок статистических гипотез вы сделали. При уровне значимости 0.1 каждый десятый раз можно получать ложный результат. Какой уровень значимости стоит применить? Если вы хотите изменить его, проделайте предыдущие пункты и проверьте свои выводы.</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7.0.7">Общий вывод</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Описание проекта
# Вы работаете в стартапе, который продаёт продукты питания. Нужно разобраться, как ведут себя пользователи вашего мобильного приложения.
# Изучите воронку продаж. Узнайте, как пользователи доходят до покупки. Сколько пользователей доходит до покупки, а сколько — «застревает» на предыдущих шагах? На каких именно?
# После этого исследуйте результаты A/A/B-эксперимента. Дизайнеры захотели поменять шрифты во всём приложении, а менеджеры испугались, что пользователям будет непривычно. Договорились принять решение по результатам A/A/B-теста. Пользователей разбили на 3 группы: 2 контрольные со старыми шрифтами и одну экспериментальную — с новыми. Выясните, какой шрифт лучше.
# Создание двух групп A вместо одной имеет определённые преимущества. Если две контрольные группы окажутся равны, вы можете быть уверены в точности проведенного тестирования. Если же между значениями A и A будут существенные различия, это поможет обнаружить факторы, которые привели к искажению результатов. Сравнение контрольных групп также помогает понять, сколько времени и данных потребуется для дальнейших тестов.
# В случае общей аналитики и A/A/B-эксперимента работайте с одними и теми же данными. В реальных проектах всегда идут эксперименты. Аналитики исследуют качество работы приложения по общим данным, не учитывая принадлежность пользователей к экспериментам.

# %% [markdown]
# # Описание данных
# Каждая запись в логе — это действие пользователя, или событие.
# EventName — название события;
# DeviceIDHash — уникальный идентификатор пользователя;
# EventTimestamp — время события;
# ExpId — номер эксперимента: 246 и 247 — контрольные группы, а 248 — экспериментальная.

# %% [markdown]
# # Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/logs_exp.csv. Скачать датасет

# %%
import pandas as pd #импортируем нужные библиотеки
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from plotly import graph_objects as go
import plotly.express as px
from datetime import datetime
from scipy import stats as st
import math as mth
import warnings
warnings.filterwarnings('ignore')

# %%
# загружаем данные
try:
    data = pd.read_csv('~/datasets/logs_exp.csv', sep="\t+", engine='python')
except:
    data = pd.read_csv('/datasets/logs_exp.csv', sep="\t+", engine='python')

data
# Out:
#                       EventName         DeviceIDHash  EventTimestamp  ExpId
# 0              MainScreenAppear  4575588528974610257      1564029816    246
# 1              MainScreenAppear  7416695313311560658      1564053102    246
# 2       PaymentScreenSuccessful  3518123091307005509      1564054127    248
# 3              CartScreenAppear  3518123091307005509      1564054127    248
# 4       PaymentScreenSuccessful  6217807653094995999      1564055322    248
# ...                         ...                  ...             ...    ...
# 244121         MainScreenAppear  4599628364049201812      1565212345    247
# 244122         MainScreenAppear  5849806612437486590      1565212439    246
# 244123         MainScreenAppear  5746969938801999050      1565212483    246
# 244124         MainScreenAppear  5746969938801999050      1565212498    246
# 244125       OffersScreenAppear  5746969938801999050      1565212517    246
#
# [244126 rows x 4 columns]

# %%
#посмотрим на общую информацию и на типы данных
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244126 entries, 0 to 244125
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   EventName       244126 non-null  object
#  1   DeviceIDHash    244126 non-null  int64
#  2   EventTimestamp  244126 non-null  int64
#  3   ExpId           244126 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 7.5+ MB

# %% [markdown]
# Итак, на первом этапе мы загрузили данные, посмотрели на типы данных, на содержимое колонок, теперь перейдем к обработке, переименуем названия столбцов и приведем колонку с датой и временем в читаемый вид.

# %% [markdown]
# # Шаг 2. Подготовьте данные
#
# ### 2.1 Замените названия столбцов на удобные для вас

# %%
data.columns = data.columns.str.lower()
data = data.rename(columns={'eventname' : 'event_name', 'deviceidhash' : 'user_id', 'eventtimestamp' : 'event_timestamp', 'expid' : 'exp_id'})
data
# Out:
#                      event_name              user_id  event_timestamp  exp_id
# 0              MainScreenAppear  4575588528974610257       1564029816     246
# 1              MainScreenAppear  7416695313311560658       1564053102     246
# 2       PaymentScreenSuccessful  3518123091307005509       1564054127     248
# 3              CartScreenAppear  3518123091307005509       1564054127     248
# 4       PaymentScreenSuccessful  6217807653094995999       1564055322     248
# ...                         ...                  ...              ...     ...
# 244121         MainScreenAppear  4599628364049201812       1565212345     247
# 244122         MainScreenAppear  5849806612437486590       1565212439     246
# 244123         MainScreenAppear  5746969938801999050       1565212483     246
# 244124         MainScreenAppear  5746969938801999050       1565212498     246
# 244125       OffersScreenAppear  5746969938801999050       1565212517     246
#
# [244126 rows x 4 columns]

# %% [markdown]
# ### 2.2 Проверьте пропуски и типы данных. Откорректируйте, если нужно

# %%
#заменим тип данных в колонках

data['exp_id'] = pd.to_numeric(data['exp_id'])

data['event_timestamp'] = data['event_timestamp'].apply(lambda x: datetime.fromtimestamp(x))

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244126 entries, 0 to 244125
# Data columns (total 4 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   event_name       244126 non-null  object
#  1   user_id          244126 non-null  int64
#  2   event_timestamp  244126 non-null  datetime64[ns]
#  3   exp_id           244126 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 7.5+ MB

# %%
#посчитаем явные дубликаты
data.duplicated().sum()
# Out:
# 413

# %%
#избавимся от них
data = data.drop_duplicates().reset_index(drop=True)
data
# Out:
#                      event_name              user_id     event_timestamp  \
# 0              MainScreenAppear  4575588528974610257 2019-07-25 04:43:36
# 1              MainScreenAppear  7416695313311560658 2019-07-25 11:11:42
# 2       PaymentScreenSuccessful  3518123091307005509 2019-07-25 11:28:47
# 3              CartScreenAppear  3518123091307005509 2019-07-25 11:28:47
# 4       PaymentScreenSuccessful  6217807653094995999 2019-07-25 11:48:42
# ...                         ...                  ...                 ...
# 243708         MainScreenAppear  4599628364049201812 2019-08-07 21:12:25
# 243709         MainScreenAppear  5849806612437486590 2019-08-07 21:13:59
# 243710         MainScreenAppear  5746969938801999050 2019-08-07 21:14:43
# 243711         MainScreenAppear  5746969938801999050 2019-08-07 21:14:58
# 243712       OffersScreenAppear  5746969938801999050 2019-08-07 21:15:17
#
#         exp_id
# 0          246
# 1          246
# 2          248
# 3          248
# ...

# %% [markdown]
# ### 2.3 Добавьте столбец даты и времени, а также отдельный столбец дат

# %%
#столбец с датой и временем мы уже отформатировали, теперь добавим отдельный столбец с датой

data['event_date'] = data['event_timestamp'].dt.date 
data
# Out:
#                      event_name              user_id     event_timestamp  \
# 0              MainScreenAppear  4575588528974610257 2019-07-25 04:43:36
# 1              MainScreenAppear  7416695313311560658 2019-07-25 11:11:42
# 2       PaymentScreenSuccessful  3518123091307005509 2019-07-25 11:28:47
# 3              CartScreenAppear  3518123091307005509 2019-07-25 11:28:47
# 4       PaymentScreenSuccessful  6217807653094995999 2019-07-25 11:48:42
# ...                         ...                  ...                 ...
# 243708         MainScreenAppear  4599628364049201812 2019-08-07 21:12:25
# 243709         MainScreenAppear  5849806612437486590 2019-08-07 21:13:59
# 243710         MainScreenAppear  5746969938801999050 2019-08-07 21:14:43
# 243711         MainScreenAppear  5746969938801999050 2019-08-07 21:14:58
# 243712       OffersScreenAppear  5746969938801999050 2019-08-07 21:15:17
#
#         exp_id  event_date
# 0          246  2019-07-25
# 1          246  2019-07-25
# ...

# %% [markdown]
# # Шаг 3. Изучите и проверьте данные

# %% [markdown]
# ### 3.1 Сколько всего событий в логе?

# %%
print('Всего событий в логе:', data['event_name'].count())
# Out:
# Всего событий в логе: 243713

# %% [markdown]
# ### 3.2 Сколько всего пользователей в логе?

# %%
print('Всего пользователей в логе:',data['user_id'].nunique())
# Out:
# Всего пользователей в логе: 7551

# %% [markdown]
# ### 3.3 Сколько в среднем событий приходится на пользователя?

# %%
display(data.groupby('user_id').agg({'event_name': 'count'}).describe())

print('В среднем событий на каждого пользователя приходится: 32')
# Out:
#         event_name
# count  7551.000000
# mean     32.275593
# std      65.154219
# min       1.000000
# 25%       9.000000
# 50%      20.000000
# 75%      37.000000
# max    2307.000000
# В среднем событий на каждого пользователя приходится: 32

# %% [markdown]
# ### 3.4 Данными за какой период вы располагаете? Найдите максимальную и минимальную дату. Постройте гистограмму по дате и времени.  Можно ли быть уверенным, что у вас одинаково полные данные за весь период? Технически в логи новых дней по некоторым пользователям могут «доезжать» события из прошлого — это может «перекашивать данные».    Определите, с какого момента данные полные и отбросьте более старые. Данными за какой период времени вы располагаете на самом деле?

# %%
print("Минимальная дата:", data['event_date'].min())

print("")

print("максимальная дата:", data['event_date'].max())
# Out:
# Минимальная дата: 2019-07-25
#
# максимальная дата: 2019-08-07

# %%
plt.figure(
    figsize=(12, 8)
)
data['event_timestamp'].hist(bins = 30 , xrot = 45).set(title = 'Гистограмма по дате и времени', 
                                                        xlabel = 'Дата', ylabel = 'Частота событий')


plt.show()

# %% [markdown]
# Глядя на гистограмму можно сделать вывод, что наши данные полные только с 1-го по 7-е августа, поэтому отбросим более старые данные.

# %%
data_new = data.query('event_timestamp >= "2019-08-01 00:00:00"')
data_new
# Out:
#                 event_name              user_id     event_timestamp  exp_id  \
# 2826              Tutorial  3737462046622621720 2019-08-01 00:07:28     246
# 2827      MainScreenAppear  3737462046622621720 2019-08-01 00:08:00     246
# 2828      MainScreenAppear  3737462046622621720 2019-08-01 00:08:55     246
# 2829    OffersScreenAppear  3737462046622621720 2019-08-01 00:08:58     246
# 2830      MainScreenAppear  1433840883824088890 2019-08-01 00:08:59     247
# ...                    ...                  ...                 ...     ...
# 243708    MainScreenAppear  4599628364049201812 2019-08-07 21:12:25     247
# 243709    MainScreenAppear  5849806612437486590 2019-08-07 21:13:59     246
# 243710    MainScreenAppear  5746969938801999050 2019-08-07 21:14:43     246
# 243711    MainScreenAppear  5746969938801999050 2019-08-07 21:14:58     246
# 243712  OffersScreenAppear  5746969938801999050 2019-08-07 21:15:17     246
#
#         event_date
# 2826    2019-08-01
# ...

# %% [markdown]
# ### 3.5 Много ли событий и пользователей вы потеряли, отбросив старые данные?

# %%
print('Количество потерянных событий составляет:', data['event_name'].count() - data_new['event_name'].count())

print('Процент событий в очищенном датафрейме:', (data_new['event_name'].count()/data['event_name'].count()*100).round(2))
# Out:
# Количество потерянных событий составляет: 2826
# Процент событий в очищенном датафрейме: 98.84

# %%
print('Количество потерянных пользователей составляет:', data['user_id'].nunique() - data_new['user_id'].nunique()) 

print('Процент уникальных пользователей в  очищенном датафрейме:',  round((data_new['user_id'].nunique()/data['user_id'].nunique()*100), 2))
# Out:
# Количество потерянных пользователей составляет: 17
# Процент уникальных пользователей в  очищенном датафрейме: 99.77

# %% [markdown]
# ### 3.6 Проверьте, что у вас есть пользователи из всех трёх экспериментальных групп.

# %%
 display(data_new.groupby('exp_id').agg({'user_id': 'nunique'}))
# Out:
#         user_id
# exp_id
# 246        2484
# 247        2513
# 248        2537

# %% [markdown]
# На данном этапе мы посчитали количество пользователей и событий в логе, отбросили более старые и неполные данные, которые могли в дальнейшем исказить наши результаты. Теперь перейдем к воронке событий.

# %% [markdown]
# # Шаг 4. Изучите воронку событий

# %% [markdown]
# ### 4.1 Посмотрите, какие события есть в логах, как часто они встречаются. Отсортируйте события по частоте.

# %%
 display(data_new.groupby('event_name').count())
# Out:
#                          user_id  event_timestamp  exp_id  event_date
# event_name
# CartScreenAppear           42303            42303   42303       42303
# MainScreenAppear          117328           117328  117328      117328
# OffersScreenAppear         46333            46333   46333       46333
# PaymentScreenSuccessful    33918            33918   33918       33918
# Tutorial                    1005             1005    1005        1005

# %% [markdown]
# У нас есть 5 событий в журнале : Главный экран, Экран предложения, Экран корзины, Экран успешной оплаты и инструкция для пользователей.

# %% [markdown]
# ### 4.2 Посчитайте, сколько пользователей совершали каждое из этих событий. Отсортируйте события по числу пользователей. Посчитайте долю пользователей, которые хоть раз совершали событие.

# %%
#сгруппируем данные по событиям, посчитаем их количество и уникальное количество пользователей, 
#которые совершали каждое из событий
funnel = (data_new.groupby('event_name').agg({'event_name': 'count', 'user_id': 'nunique'})
                                   .rename(columns = {'event_name': 'event_count', 'user_id': 'unique_user_count'})
                                   .sort_values(by = 'unique_user_count', ascending = False).reset_index())
funnel
# Out:
#                 event_name  event_count  unique_user_count
# 0         MainScreenAppear       117328               7419
# 1       OffersScreenAppear        46333               4593
# 2         CartScreenAppear        42303               3734
# 3  PaymentScreenSuccessful        33918               3539
# 4                 Tutorial         1005                840

# %%
#построим воронку продаж без учета шага Tutorial, он не относится непосредственно к воронке продаж.



fig = go.Figure(
    go.Funnel(
        y=[
            'Главный экран',
            'Экран предложения',
            'Экран корзины',
            'Экран успешной оплаты',
        ],
        x= funnel.loc[:4,'unique_user_count'],
    )
)

fig.update_layout(title_text='Воронка продаж', title_x=0.5)
fig.show()
# Out:
# <div>                            <div id="45b984c5-902a-4a86-aeb5-d71e64bccb62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45b984c5-902a-4a86-aeb5-d71e64bccb62")) {                    Plotly.newPlot(                        "45b984c5-902a-4a86-aeb5-d71e64bccb62",                        [{"x":[7419,4593,3734,3539,840],"y":["\u0413\u043b\u0430\u0432\u043d\u044b\u0439 \u044d\u043a\u0440\u0430\u043d","\u042d\u043a\u0440\u0430\u043d \u043f\u0440\u0435\u0434\u043b\u043e\u0436\u0435\u043d\u0438\u044f","\u042d\u043a\u0440\u0430\u043d \u043a\u043e\u0440\u0437\u0438\u043d\u044b","\u042d\u043a\u0440\u0430\u043d \u0443\u0441\u043f\u0435\u0448\u043d\u043e\u0439 \u043e\u043f\u043b\u0430\u0442\u044b"],"type":"funnel"}],                        {"template":{"dat
# ...

# %%
# Посчитаем долю пользователей, которые хоть раз совершали событие
funnel['%_unique_user'] = funnel['unique_user_count']/funnel['unique_user_count'].values[0] * 100
funnel
# Out:
#                 event_name  event_count  unique_user_count  %_unique_user
# 0         MainScreenAppear       117328               7419     100.000000
# 1       OffersScreenAppear        46333               4593      61.908613
# 2         CartScreenAppear        42303               3734      50.330233
# 3  PaymentScreenSuccessful        33918               3539      47.701847
# 4                 Tutorial         1005                840      11.322281

# %% [markdown]
# ### 4.3 Предположите, в каком порядке происходят события. Все ли они выстраиваются в последовательную цепочку? Их не нужно учитывать при расчёте воронки.

# %% [markdown]
# Исходя из событий в таблице выше можно предположить:
# 1. Увидел главную страницу
# 2. Увидел инструкцию
# 3. Перешел на страницу с предложением
# 4. Добавил товар в корзину
# 5. Перешел на страницу оплаты

# %%
display(data_new.query('event_name == "PaymentScreenSuccessful"'))
#сделаем срез по PaymentScreenSuccessful, посмотрим на пользователей, которые доходяд до оплаты, 
#через какие этапы они проходят вообще.
# Out:
#                      event_name              user_id     event_timestamp  \
# 2845    PaymentScreenSuccessful  4613461174774205834 2019-08-01 00:14:43
# 2861    PaymentScreenSuccessful  2712290788139738557 2019-08-01 00:22:44
# 2865    PaymentScreenSuccessful  2712290788139738557 2019-08-01 00:23:08
# 2869    PaymentScreenSuccessful  2712290788139738557 2019-08-01 00:23:20
# 2871    PaymentScreenSuccessful  2712290788139738557 2019-08-01 00:23:34
# ...                         ...                  ...                 ...
# 243600  PaymentScreenSuccessful  7369756705772294430 2019-08-07 20:56:44
# 243612  PaymentScreenSuccessful  7369756705772294430 2019-08-07 20:56:56
# 243636  PaymentScreenSuccessful  2640177033729351241 2019-08-07 20:59:05
# 243667  PaymentScreenSuccessful  8249271441488197538 2019-08-07 21:03:32
# 243689  PaymentScreenSuccessful  2431247070435249376 2019-08-07 21:07:08
#
#         exp_id  event_date
# 2845       248  2019-08-01
# 2861       247  2019-08-01
# ...

# %%
display(data.query('user_id == 8249271441488197538').sort_values(by = 'event_timestamp').head(30))


display(data.query('user_id == 4613461174774205834').sort_values(by = 'event_timestamp').head(30))
# Out:
#                      event_name              user_id     event_timestamp  \
# 1864         OffersScreenAppear  8249271441488197538 2019-07-31 18:58:10
# 134306         MainScreenAppear  8249271441488197538 2019-08-04 17:25:10
# 134310       OffersScreenAppear  8249271441488197538 2019-08-04 17:25:21
# 134325       OffersScreenAppear  8249271441488197538 2019-08-04 17:25:53
# 134341  PaymentScreenSuccessful  8249271441488197538 2019-08-04 17:26:12
# 134342         CartScreenAppear  8249271441488197538 2019-08-04 17:26:14
# 134592       OffersScreenAppear  8249271441488197538 2019-08-04 17:34:51
# 134624         MainScreenAppear  8249271441488197538 2019-08-04 17:35:38
# 134670         MainScreenAppear  8249271441488197538 2019-08-04 17:36:35
# 134675       OffersScreenAppear  8249271441488197538 2019-08-04 17:36:46
# 134745       OffersScreenAppear  8249271441488197538 2019-08-04 17:38:27
# 243666         MainScreenAppear  8249271441488197538 2019-08-07 21:03:29
# ...

# %% [markdown]
# ### 4.4 По воронке событий посчитайте, какая доля пользователей проходит на следующий шаг воронки (от числа пользователей на предыдущем). То есть для последовательности событий A → B → C посчитайте отношение числа пользователей с событием B к количеству пользователей с событием A, а также отношение числа пользователей с событием C к количеству пользователей с событием B.

# %%
#сделаем срез данных, Tutorial в воронке продаж не учавствует
funnel = funnel.query('event_name != "Tutorial"')

funnel['conv'] = funnel['unique_user_count'] / funnel['unique_user_count'].values[0]
funnel['prev_step'] = funnel['unique_user_count'].shift() # сдвигает столбец user на одну строку вниз
funnel['step_conv'] = funnel['unique_user_count'] / funnel['prev_step'] # конверсия в следущий шаг
display(funnel)
# Out:
#                 event_name  event_count  unique_user_count  %_unique_user  \
# 0         MainScreenAppear       117328               7419     100.000000
# 1       OffersScreenAppear        46333               4593      61.908613
# 2         CartScreenAppear        42303               3734      50.330233
# 3  PaymentScreenSuccessful        33918               3539      47.701847
#
#        conv  prev_step  step_conv
# 0  1.000000        NaN        NaN
# 1  0.619086     7419.0   0.619086
# 2  0.503302     4593.0   0.812976
# 3  0.477018     3734.0   0.947777

# %% [markdown]
# ### 4.5 На каком шаге теряете больше всего пользователей? Какая доля пользователей доходит от первого события до оплаты?

# %% [markdown]
# Больше всего пользователей теряется между первым и вторым шагом при переходе из MainScreenAppea в OffersScreenAppear.
#
# примерно 48 % пользователей доходят от первого этапа до оплаты заказа.

# %% [markdown]
# На этом шаге мы построили и изучили воронку событий, определили какие события входят в воронку продаж, на каком шаге мы теряем больше всего пользователей и рассчитали конверсию.

# %% [markdown]
# # Шаг 5. Изучите результаты эксперимента

# %% [markdown]
# ### 5.1 Сколько пользователей в каждой экспериментальной группе?

# %%
data_exp = data_new.query('event_name != "Tutorial"')

#сделаем группировку по экспериментальным группам и посчитаем количество пользователей
trials = data_exp.groupby('exp_id').agg({'user_id': 'nunique'})
display(trials)


#в этом датафрейме сохраним число пользователей по событиям.
df = data_exp.pivot_table(index = 'event_name', columns = 'exp_id', values = 'user_id', aggfunc = 'nunique')

display(df)
# Out:
#         user_id
# exp_id
# 246        2483
# 247        2512
# 248        2535
# exp_id                    246   247   248
# event_name
# CartScreenAppear         1266  1238  1230
# MainScreenAppear         2450  2476  2493
# OffersScreenAppear       1542  1520  1531
# PaymentScreenSuccessful  1200  1158  1181

# %%
duplicated_users = data_exp.groupby('user_id').agg({'exp_id':['nunique', 'unique']})
duplicated_users.columns = ['groups', 'group_name']
duplicated_users = duplicated_users.query('groups > 1')
print('Количество пересекающихся пользователей', duplicated_users['groups'].count())
# Out:
# Количество пересекающихся пользователей 0

# %% [markdown]
# ### 5.2 Есть 2 контрольные группы для А/А-эксперимента, чтобы проверить корректность всех механизмов и расчётов. Проверьте, находят ли статистические критерии разницу между выборками 246 и 247.
#
# ### +
#
# ### 5.3 Выберите самое популярное событие. Посчитайте число пользователей, совершивших это событие в каждой из контрольных групп. Посчитайте долю пользователей, совершивших это событие. Проверьте, будет ли отличие между группами статистически достоверным. Проделайте то же самое для всех других событий (удобно обернуть проверку в отдельную функцию). Можно ли сказать, что разбиение на группы работает корректно?

# %% [markdown]
# В тесте мы будем проверять следующие гипотезы:
# - H0 между выборками есть значимая разница
#
# - H1 между выборками нет значимой разницы
#
# критический уровень статистической значимости 0.05

# %%
alpha = 0.05  # критический уровень статистической значимости
def check_hypothesis(suc1, suc2, tr1, tr2):

    successes = np.array([suc1, suc2]) 
    trials = np.array([tr1, tr2])

    # пропорция успехов в первой группе:
    p1 = successes[0]/trials[0]

    # пропорция успехов во второй группе:
    p2 = successes[1]/trials[1]

    # пропорция успехов в комбинированном датасете:
    p_combined = (successes[0] + successes[1]) / (trials[0] + trials[1])

    # разница пропорций в датасетах
    difference = p1 - p2 

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference / mth.sqrt(p_combined * (1 - p_combined) * (1/trials[0] + 1/trials[1]))

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)  

    # считаем статистику в ст.отклонениях стандартного нормального распределения
    z_value = difference / mth.sqrt(
        p_combined * (1 - p_combined) * (1 / trials[0] + 1 / trials[1])
    )

    # задаем стандартное нормальное распределение (среднее 0, ст.отклонение 1)
    distr = st.norm(0, 1)

    p_value = (1 - distr.cdf(abs(z_value))) * 2
    
    
    
    return p_value

# %%
def analyze_groups(target_groups, target_alpha, t1_label, t2_label):
    p_values = []
    # перебираем все нужные сочетания групп
    for groups in target_groups:
        # перебираем все события в воронке
        for event in data_exp['event_name'].unique():
            # сохраняете результаты
            p = check_hypothesis (df.loc[event, groups[0]], df.loc[event, groups[1]],
                                  trials.loc[groups[0]].values[0], trials.loc [groups[1]].values[0])
            p_values += [[groups [0], groups [1], event, p]]

    p_values = pd. DataFrame (p_values, columns = [t1_label, t2_label, 'event_name', 'p-value'])
    # коррекция Бонферрони
    alpha = target_alpha / p_values.shape [0] #делим на число экспериментов
    p_values['reject_ho'] = p_values['p-value'] < alpha
    return p_values
    

display(analyze_groups([[246, 247]], 0.05, "A", "A"))
# Out:
#      A    A               event_name   p-value  reject_ho
# 0  246  247         MainScreenAppear  0.752670      False
# 1  246  247       OffersScreenAppear  0.247861      False
# 2  246  247         CartScreenAppear  0.228676      False
# 3  246  247  PaymentScreenSuccessful  0.114466      False

# %% [markdown]
# Итог: между группами А/А нет никак статистически значимых различий, при прохождении воронок, группы эквивалентны.

# %% [markdown]
# ### 5.4 Аналогично поступите с группой с изменённым шрифтом. Сравните результаты с каждой из контрольных групп в отдельности по каждому событию. Сравните результаты с объединённой контрольной группой. Какие выводы из эксперимента можно сделать?

# %%
#для начала добавим в таблицу объединенную группу 246+247


summed = data_exp.query('exp_id in [246, 247]')
summed['exp_id'] = '246 + 247'

data_exp = data_exp.append(summed)


trials = data_exp.groupby('exp_id').agg({'user_id': 'nunique'})
display(trials)


df = data_exp.pivot_table(index = 'event_name', columns = 'exp_id', values = 'user_id', aggfunc = 'nunique')
display(df)
# Out:
#            user_id
# exp_id
# 246           2483
# 247           2512
# 248           2535
# 246 + 247     4995
# exp_id                    246   247   248  246 + 247
# event_name
# CartScreenAppear         1266  1238  1230       2504
# MainScreenAppear         2450  2476  2493       4926
# OffersScreenAppear       1542  1520  1531       3062
# PaymentScreenSuccessful  1200  1158  1181       2358

# %%
# теперь запустим в работу нашу функцию
display(analyze_groups([[246, 248], [247, 248], ['246 + 247', 248]], 0.05, "A", "B"))
# Out:
#             A    B               event_name   p-value  reject_ho
# 0         246  248         MainScreenAppear  0.338711      False
# 1         246  248       OffersScreenAppear  0.214425      False
# 2         246  248         CartScreenAppear  0.080674      False
# 3         246  248  PaymentScreenSuccessful  0.216930      False
# 4         247  248         MainScreenAppear  0.519496      False
# 5         247  248       OffersScreenAppear  0.933375      False
# 6         247  248         CartScreenAppear  0.587828      False
# 7         247  248  PaymentScreenSuccessful  0.727572      False
# 8   246 + 247  248         MainScreenAppear  0.348668      False
# 9   246 + 247  248       OffersScreenAppear  0.445827      False
# 10  246 + 247  248         CartScreenAppear  0.186836      False
# 11  246 + 247  248  PaymentScreenSuccessful  0.610792      False

# %% [markdown]
# Результат получается таким же, как и при проверке А/А теста, при  уровне значимости 0.05  между группами нет никак статистически значимых различий.

# %% [markdown]
# ### 5.5 Какой уровень значимости вы выбрали при проверке статистических гипотез выше? Посчитайте, сколько проверок статистических гипотез вы сделали. При уровне значимости 0.1 каждый десятый раз можно получать ложный результат. Какой уровень значимости стоит применить? Если вы хотите изменить его, проделайте предыдущие пункты и проверьте свои выводы.

# %% [markdown]
# В предыдущих пунктах мы провели всего 16 тестов, с уровнем значимости 0.05, попробуем увеличить уровень значимости до 0.1 и сравним результаты.

# %%
display(analyze_groups([[246, 247]], 0.1, "A", "A"))
# Out:
#      A    A               event_name   p-value  reject_ho
# 0  246  247         MainScreenAppear  0.752670      False
# 1  246  247       OffersScreenAppear  0.247861      False
# 2  246  247         CartScreenAppear  0.228676      False
# 3  246  247  PaymentScreenSuccessful  0.114466      False

# %%
display(analyze_groups([[246, 248], [247, 248], ['246 + 247', 248]], 0.1, "A", "B"))
# Out:
#             A    B               event_name   p-value  reject_ho
# 0         246  248         MainScreenAppear  0.338711      False
# 1         246  248       OffersScreenAppear  0.214425      False
# 2         246  248         CartScreenAppear  0.080674      False
# 3         246  248  PaymentScreenSuccessful  0.216930      False
# 4         247  248         MainScreenAppear  0.519496      False
# 5         247  248       OffersScreenAppear  0.933375      False
# 6         247  248         CartScreenAppear  0.587828      False
# 7         247  248  PaymentScreenSuccessful  0.727572      False
# 8   246 + 247  248         MainScreenAppear  0.348668      False
# 9   246 + 247  248       OffersScreenAppear  0.445827      False
# 10  246 + 247  248         CartScreenAppear  0.186836      False
# 11  246 + 247  248  PaymentScreenSuccessful  0.610792      False

# %% [markdown]
# Результаты теста не поменялись, не зависимо от уровня стат.значимости между группами нет значимой разницы.
# Также хочу добавить, что при одновременной проверки большего числа гипотез мы использовали метод Бонферрони.

# %% [markdown]
# ### Общий вывод
#
# Мы провели анализ и построили воронку продаж, посмотрели как и в каком количестве пользователи доходят до покупки товаров. Определили что больше всего пользователей теряется между первым и вторым шагом при переходе из MainScreenAppea в OffersScreenAppear. Далее перед нами стояла задача исследовать результаты A/A/B-эксперимента, так как дизайнеры захотели поменять шрифты во всём приложении, нам необходимо было выяснить какой шрифт всё таки лучше. В результате эксперимента мы пришли к выводу, что между группами нет никак статистически значимых различий, следовательно шрифт никак не влияет на поведение пользователей.
