# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1">Описание проекта</a></span><ul class="toc-item"><li><span><a href="#Задача" data-toc-modified-id="Задача-1.1">Задача</a></span></li><li><span><a href="#Инструкция-по-выполнению-проекта" data-toc-modified-id="Инструкция-по-выполнению-проекта-1.2">Инструкция по выполнению проекта</a></span></li><li><span><a href="#Шаг-1.-Загрузите-данные" data-toc-modified-id="Шаг-1.-Загрузите-данные-1.3">Шаг 1. Загрузите данные</a></span></li><li><span><a href="#Шаг-2.-Проведите-исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Шаг-2.-Проведите-исследовательский-анализ-данных-(EDA)-1.4">Шаг 2. Проведите исследовательский анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#2.1-Посмотрите-на-датасет:-есть-ли-в-нем-отсутствующие-признаки,-изучите-средние-значения-и-стандартные-отклонения-(пригодится-метод-describe());" data-toc-modified-id="2.1-Посмотрите-на-датасет:-есть-ли-в-нем-отсутствующие-признаки,-изучите-средние-значения-и-стандартные-отклонения-(пригодится-метод-describe());-1.4.1">2.1 Посмотрите на датасет: есть ли в нем отсутствующие признаки, изучите средние значения и стандартные отклонения (пригодится метод describe());</a></span></li><li><span><a href="#2.2-Посмотрите-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-(воспользуйтесь-методом-groupby());" data-toc-modified-id="2.2-Посмотрите-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-(воспользуйтесь-методом-groupby());-1.4.2">2.2 Посмотрите на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby());</a></span></li><li><span><a href="#2.3-Постройте-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток);" data-toc-modified-id="2.3-Постройте-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток);-1.4.3">2.3 Постройте столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);</a></span></li><li><span><a href="#2.4-Постройте-матрицу-корреляций-и-отобразите-её." data-toc-modified-id="2.4-Постройте-матрицу-корреляций-и-отобразите-её.-1.4.4">2.4 Постройте матрицу корреляций и отобразите её.</a></span></li></ul></li><li><span><a href="#Шаг-3.-Постройте-модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Шаг-3.-Постройте-модель-прогнозирования-оттока-клиентов-1.5">Шаг 3. Постройте модель прогнозирования оттока клиентов</a></span></li><li><span><a href="#Шаг-4.-Сделайте-кластеризацию-клиентов" data-toc-modified-id="Шаг-4.-Сделайте-кластеризацию-клиентов-1.6">Шаг 4. Сделайте кластеризацию клиентов</a></span><ul class="toc-item"><li><span><a href="#4.1-Отложите-в-сторону-столбец-с-оттоком-и-проведите-кластеризацию-объектов-(клиентов):" data-toc-modified-id="4.1-Отложите-в-сторону-столбец-с-оттоком-и-проведите-кластеризацию-объектов-(клиентов):-1.6.1">4.1 Отложите в сторону столбец с оттоком и проведите кластеризацию объектов (клиентов):</a></span></li><li><span><a href="#4.2-Обучите-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозируйте-кластеры-клиентов.-Договоримся-за-число-кластеров-принять-n=5,-чтобы-ваши-результаты-можно-было-сравнивать-с-результатами-остальных-студентов.-Однако,-конечно,-в-жизни-никто-не-скажет-вам-правильный-ответ,-и-решение-остаётся-за-вами-(на-основании-изучения-графика-из-предыдущего-пункта)." data-toc-modified-id="4.2-Обучите-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозируйте-кластеры-клиентов.-Договоримся-за-число-кластеров-принять-n=5,-чтобы-ваши-результаты-можно-было-сравнивать-с-результатами-остальных-студентов.-Однако,-конечно,-в-жизни-никто-не-скажет-вам-правильный-ответ,-и-решение-остаётся-за-вами-(на-основании-изучения-графика-из-предыдущего-пункта).-1.6.2">4.2 Обучите модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы ваши результаты можно было сравнивать с результатами остальных студентов. Однако, конечно, в жизни никто не скажет вам правильный ответ, и решение остаётся за вами (на основании изучения графика из предыдущего пункта).</a></span></li><li><span><a href="#4.3-Посмотрите-на-средние-значения-признаков-для-кластеров.-Можно-ли-сразу-что-то-заметить?" data-toc-modified-id="4.3-Посмотрите-на-средние-значения-признаков-для-кластеров.-Можно-ли-сразу-что-то-заметить?-1.6.3">4.3 Посмотрите на средние значения признаков для кластеров. Можно ли сразу что-то заметить?</a></span></li><li><span><a href="#4.4-Постройте-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?" data-toc-modified-id="4.4-Постройте-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?-1.6.4">4.4 Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?</a></span></li><li><span><a href="#4.5-Для-каждого-полученного-кластера-посчитайте-долю-оттока-(методом-groupby()).-Отличаются-ли-они-по-доле-оттока?-Какие-кластеры-склонны-к-оттоку,-а-какие-—-надёжны?" data-toc-modified-id="4.5-Для-каждого-полученного-кластера-посчитайте-долю-оттока-(методом-groupby()).-Отличаются-ли-они-по-доле-оттока?-Какие-кластеры-склонны-к-оттоку,-а-какие-—-надёжны?-1.6.5">4.5 Для каждого полученного кластера посчитайте долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?</a></span></li></ul></li><li><span><a href="#Шаг-5.-Сформулируйте-выводы-и-сделайте-базовые-рекомендации-по-работе-с-клиентами" data-toc-modified-id="Шаг-5.-Сформулируйте-выводы-и-сделайте-базовые-рекомендации-по-работе-с-клиентами-1.7">Шаг 5. Сформулируйте выводы и сделайте базовые рекомендации по работе с клиентами</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Описание проекта
#
# ## Задача
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных.
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов.
# Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество клиентских анкет. Ваша задача — провести анализ и подготовить план действий по удержанию клиентов.
# А именно:
#
#    научиться прогнозировать вероятность оттока (на уровне следующего месяца) для каждого клиента;
#    сформировать типичные портреты клиентов: выделить несколько наиболее ярких групп и охарактеризовать их основные свойства;
#    проанализировать основные признаки, наиболее сильно влияющие на отток;
#    сформулировать основные выводы и разработать рекомендации по повышению качества работы с клиентами:
#     1) выделить целевые группы клиентов;
#     2) предложить меры по снижению оттока;
#     3) определить другие особенности взаимодействия с клиентами.

# %% [markdown]
# ## Инструкция по выполнению проекта
#
# ## Шаг 1. Загрузите данные
# Путь к файлу: /datasets/gym_churn.csv

# %%
#импортируем нужные библиотеки
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy.cluster.hierarchy import dendrogram, linkage 
from sklearn.cluster import KMeans


try:
    data = pd.read_csv('~/datasets/gym_churn.csv') #загружаем данные
except:
    data = pd.read_csv('/datasets/gym_churn.csv')

data
# Out:
#       gender  Near_Location  Partner  Promo_friends  Phone  Contract_period  \
# 0          1              1        1              1      0                6
# 1          0              1        0              0      1               12
# 2          0              1        1              0      1                1
# 3          0              1        1              1      1               12
# 4          1              1        1              1      1                1
# ...      ...            ...      ...            ...    ...              ...
# 3995       1              1        1              0      1               12
# 3996       0              1        0              0      1                1
# 3997       1              1        1              1      1               12
# 3998       0              1        1              1      1                6
# 3999       1              0        1              0      0               12
#
# ...

# %% [markdown]
# Все необходимые библиотеки мы подгрузили и сохранили наш датафрейм в переменной можно двигаться дальше.

# %% [markdown]
# ## Шаг 2. Проведите исследовательский анализ данных (EDA)
#
# ### 2.1 Посмотрите на датасет: есть ли в нем отсутствующие признаки, изучите средние значения и стандартные отклонения (пригодится метод describe());

# %%
print(data.shape)


print(data.info())
# Out:
# (4000, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   int64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# Исходя из выше приведенных данных мы имеем дело с числовыми признаками, пропусков в датасете нет, всего у нас 4000 тыс наблюдений и 14 столбцов

# %%
data.describe() #посмотрим на средние значения и стандартные отклонения
# Out:
#             gender  Near_Location      Partner  Promo_friends        Phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        Contract_period  Group_visits          Age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %% [markdown]
# Исходя из данных можно сказать, что во всех колонках разное распределение данных, например если посмотреть на возраст, то можно отметить что распределение скорее всего будет приближено к нормальному, а вот если обратиться к колонке суммарная выручка от других услуг фитнес-центра то распределение величины будет явно ненормальным.

# %% [markdown]
# ### 2.2 Посмотрите на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby());

# %%
data.groupby(['Churn']).mean()
# Out:
#          gender  Near_Location   Partner  Promo_friends     Phone  \
# Churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        Contract_period  Group_visits        Age  Avg_additional_charges_total  \
# Churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        Month_to_end_contract  Lifetime  Avg_class_frequency_total  \
# Churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        Avg_class_frequency_current_month
# Churn
# 0                               2.027882
# 1                               1.044546

# %% [markdown]
# Разброс величин разный, у некоторых признаков разница в среднем незначительная, а у других заметно отличается. Можем сразу сказать, что скорее всего половой признак никак не влияет на отток, телефон тоже никакого отношения не имеет, а вот признак Promo_friends (факт первоначальной записи в рамках акции «приведи друга») уже может оказывать влияние, Contract_period и Lifetime тоже имеет значение, видимо чаще перестают ходить те, кто купил месячный абонемент, нежели полугодовой. Признак Group_visits намекает нам на то, что любители групповых занятий более надежные клиенты.

# %% [markdown]
# ### 2.3 Постройте столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);

# %%
iterate_columns = data.drop(columns = ['Churn']).columns.values.tolist()

# напишем цикл для построения гистограмм
for column in iterate_columns:
    plt.figure(figsize=(10, 5))
    sns.histplot(data=data, x=column, hue="Churn", multiple="dodge")
    plt.title(column)  

    plt.show()

# %% [markdown]
# Графики мы построили, чтобы посмотреть на распределение признаков и оценить выбросы, так как мы имеем дело с логическими переменными у некоторых признаков сложно оценить распределение ,его можно оценить скорее всего только на нескольких графиках, например признак возраст имеет нормальное распределение, Avg_additional_charges_total, Avg_class_frequency_total, Avg_class_frequency_current_month явно имеют не нормальное распределение. Аномальных значений и выбросов у нас нет.

# %% [markdown]
# ### 2.4 Постройте матрицу корреляций и отобразите её.

# %%
cm = data.corr() #вычисляем матрицу корреляций

plt.figure(figsize =(12, 12))
#нарисуем тепловую карту с подписями для матрицы корреляций
sns.heatmap(cm, annot=True, square=True)
ax.set_ylim(
    13, 0
)  # корректировка "рваных" полей heatmap в последней версии библиотеки
#plt.show()
# Out:
# (13.0, 0.0)

# %% [markdown]
# Можно увидеть пару скоррелированных признаков, для этого удалим по одному признаку, для того чтобы наши модели прогнозирования из-за мультиколлинеарности не давали сбой.

# %%
data_new = data.drop(columns = ['Contract_period', 'Avg_class_frequency_total'])
data_new
# Out:
#       gender  Near_Location  Partner  Promo_friends  Phone  Group_visits  Age  \
# 0          1              1        1              1      0             1   29
# 1          0              1        0              0      1             1   31
# 2          0              1        1              0      1             0   28
# 3          0              1        1              1      1             1   33
# 4          1              1        1              1      1             0   26
# ...      ...            ...      ...            ...    ...           ...  ...
# 3995       1              1        1              0      1             0   33
# 3996       0              1        0              0      1             1   29
# 3997       1              1        1              1      1             0   28
# 3998       0              1        1              1      1             0   32
# 3999       1              0        1              0      0             1   30
#
# ...

# %% [markdown]
# На этом шаге мы провели EDA, выявили что пропусков и аномалий в значениях нет и избавились от мультиколлинеарности, дальше будем строить модель прогнозирования оттока клиентов.

# %% [markdown]
# ## Шаг 3. Постройте модель прогнозирования оттока клиентов
#
# Постройте модель бинарной классификации клиентов, где целевой признак — факт оттока клиента в следующем месяце:
#
#    1) Разбейте данные на обучающую и валидационную выборку функцией train_test_split().
#
#    2) Обучите модель на train-выборке двумя способами:
#
#         - логистической регрессией
#
#         - случайным лесом.
#
#    3) Оцените метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?
#
# Не забудьте указать параметр random_state при разделении выборки и задании алгоритма.

# %%
#разделим наши данные на признаки (матрица X) и целевую переменную (y)
X = data_new.drop('Churn', axis = 1)
y = data_new['Churn']

# разделим модель на обучающую и валидационную выборку
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=0)

# обучим StandartScaler на обучающей выборке
scaler = StandardScaler()
scaler.fit(X_train)


# Преобразуйте обучающий и валидационные наборы данных
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

# зададим алгоритм для нашей модели 
model = LogisticRegression(random_state=0) 

# обучим модель
model.fit(X_train_st, y_train) 

# воспользуемся уже обученной моделью, чтобы сделать прогнозы
predictions = model.predict(X_test_st) 
probabilities = model.predict_proba(X_test_st)[:,1]


print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, predictions)))
print('Recall: {:.2f}'.format(recall_score (y_test, predictions)))
# Out:
# Accuracy: 0.91
# Precision: 0.80
# Recall: 0.82

# %% [markdown]
# что можем сказать исходя из выведенных метрик, метрика Accuracy на хорошем уровне- это значит, что мы прогнозируем более 90% ответов из всех прогнозов, метрика Precision показывает долю истинно положительных исходов из всех положительных прогнозов, у нас 80%, далее метрика recall показывает, сколько реальных истинно положительных исходов мы смогли обнаружить с помощью модели - в нашем случае 82%.

# %%
model_fc =  RandomForestClassifier(n_estimators = 100, random_state=0) 

# обучим модель
model_fc.fit(X_train_st, y_train) 

# воспользуемся уже обученной моделью, чтобы сделать прогнозы
fc_predictions = model_fc.predict(X_test_st) 
fc_probabilities = model_fc.predict_proba(X_test_st)[:,1]


print('Accuracy: {:.2f}'.format(accuracy_score(y_test, fc_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, fc_predictions)))
print('Recall: {:.2f}'.format(recall_score (y_test, fc_predictions)))
# Out:
# Accuracy: 0.91
# Precision: 0.82
# Recall: 0.78

# %% [markdown]
# В этой модели метрики немного видоизменились, Precision слегка вырос, а вот Recall понизился на 4%
# Исходя из приведенных данных можно сделать вывод, что первая модель в целом срабатывает лучше. Я бы выбрала ее

# %% [markdown]
# На этом этапе мы построили модели прогнозирования оттока клиентов и пришли к выводу, что модель логистической регрессией показала себя лучше.

# %% [markdown]
# ## Шаг 4. Сделайте кластеризацию клиентов
#
# ### 4.1 Отложите в сторону столбец с оттоком и проведите кластеризацию объектов (клиентов):
#
# Стандартизируйте данные.
# Постройте матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуйте дендрограмму. Внимание: отрисовка дендрограммы может занять время! На основании полученного графика предположите, какое количество кластеров можно выделить.

# %%
# стандартизируем данные

sc = StandardScaler()
x_sc = sc.fit_transform(data_new.drop(columns = ['Churn']))

#передаем получившуюся стандартизированную таблицу в качестве параметра функции linkage()
linked = linkage(x_sc, method = 'ward') 

plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')

plt.show()

# %% [markdown]
# В итоге у нас получается пять кластеров, пять разных цветов.

# %% [markdown]
# ### 4.2 Обучите модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов. Договоримся за число кластеров принять n=5, чтобы ваши результаты можно было сравнивать с результатами остальных студентов. Однако, конечно, в жизни никто не скажет вам правильный ответ, и решение остаётся за вами (на основании изучения графика из предыдущего пункта).

# %%
# задаём модель k_means с числом кластеров 5 и фиксируем значение random_state
km = KMeans(n_clusters=5, random_state=0)

# прогнозируем кластеры для наблюдений (алгоритм присваивает им номера от 0 до 4)
labels = km.fit_predict(x_sc)

# сохраняем метки кластера в поле нашего датасета
data_new['cluster_km'] = labels

data_new
# Out:
#       gender  Near_Location  Partner  Promo_friends  Phone  Group_visits  Age  \
# 0          1              1        1              1      0             1   29
# 1          0              1        0              0      1             1   31
# 2          0              1        1              0      1             0   28
# 3          0              1        1              1      1             1   33
# 4          1              1        1              1      1             0   26
# ...      ...            ...      ...            ...    ...           ...  ...
# 3995       1              1        1              0      1             0   33
# 3996       0              1        0              0      1             1   29
# 3997       1              1        1              1      1             0   28
# 3998       0              1        1              1      1             0   32
# 3999       1              0        1              0      0             1   30
#
# ...

# %% [markdown]
# ### 4.3 Посмотрите на средние значения признаков для кластеров. Можно ли сразу что-то заметить?

# %%
# выводим статистику по средним значениям наших признаков по кластеру

clusters = data_new.drop(columns = ['Churn']).groupby(['cluster_km']).mean()
print(clusters)
# Out:
#               gender  Near_Location   Partner  Promo_friends     Phone  \
# cluster_km
# 0           0.492000       0.994000  0.953000       1.000000  0.906000
# 1           0.495352       0.998672  0.378486       0.046481  0.903054
# 2           0.511194       1.000000  0.226368       0.114428  0.899254
# 3           0.502455       0.000000  0.489362       0.072013  0.913257
# 4           0.550481       0.998798  0.274038       0.075721  0.897837
#
#             Group_visits        Age  Avg_additional_charges_total  \
# cluster_km
# 0               0.528000  29.633000                    154.086252
# 1               0.000000  30.342629                    174.392898
# 2               0.182836  26.807214                    111.073289
# 3               0.232406  28.700491                    137.375245
# 4               1.000000  30.248798                    155.206260
#
#             Month_to_end_contract  Lifetime  Avg_class_frequency_current_month
# cluster_km
# ...

# %% [markdown]
# Можно отметить,что самые заметные различия в средних значениях в колонках 'Month_to_end_contract' (срок до окончания текущего действующего абонемента (в месяцах)),'Lifetime' (время с момента первого обращения в фитнес-центр (в месяцах)), 'Partner' сотрудник компании-партнёра клуба , 'Group_visits'  факт посещения групповых занятий и Avg_class_frequency_current_month ( средняя частота посещений в неделю за предыдущий месяц) - это основные признаки по которым алгоритм делил на кластеры.

# %% [markdown]
# ### 4.4 Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?

# %%
iterate_columns = data_new.drop(columns = ['Churn', 'cluster_km']).columns.values.tolist()


for column in iterate_columns:

    plt.figure(figsize=(12, 10))

    sns.displot(data=data_new, x= column, hue='cluster_km', kind='kde', palette=sns.color_palette('bright')[:5], fill=True,  height=5, aspect=1.5)
    
    plt.title(column)
plt.show()
# Out:
# C:\Users\sgusa\anaconda3\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# C:\Users\sgusa\anaconda3\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# C:\Users\sgusa\anaconda3\lib\site-packages\seaborn\distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# Судя по распределениям на графике можно заметить, по некоторым признакам кластеры несильно отличаются, но по другим тот или иной кластер выделяется, например Partner - здесь выделяется нулевой кластер, далее в Group_visits - кластер 0 и кластер 2, причем у них достаточно сильно отличаются средние значения, значит в одной группе клиенты, которые любят групповые занятия , а в другом кластере наоборот те, кто их не посещает, в признаке Age больше выделяется второй и нулевой кластеры, во втором средний возраст посетителей 26 лет, а в нулевом 29, на последних трех графиках  Month_to_end_contract  Lifetime  Avg_class_frequency_current_month больше наверное выделяется второй кластер, где средняя частота посещений за последний месяц самая низкая из всех пяти кластеров.

# %% [markdown]
# ### 4.5 Для каждого полученного кластера посчитайте долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?

# %%
data_new.groupby('cluster_km')['Churn'].count()
# Out:
# cluster_km
# 0    1000
# 1     753
# 2     804
# 3     611
# 4     832
# Name: Churn, dtype: int64

# %%
churned = data_new.query('Churn == 1');
churned_len = len(churned.index);

churned_by_cluster = churned.groupby('cluster_km')['Churn'].count()

cluster_km_churn_perc = (churned_by_cluster/churned_len*100).round(2).reset_index()
display(cluster_km_churn_perc)
# Out:
#    cluster_km  Churn
# 0           0  10.18
# 1           1   3.30
# 2           2  56.17
# 3           3  23.09
# 4           4   7.26

# %%
cluster_km_churn_perc.sort_values('Churn', inplace=False).plot(y='Churn', kind='bar', legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Из всех кластеров наиболее подвержен оттоку второй (уровень оттока 56%), далее с большим отрывом третий (отток 23%) и нулевой (отток 10%), самые надежные первый (3.3%) и четвертый (7.2%)
#
# На этом этапе мы провели кластеризацию клиентов, определили какие группы (кластеры) наиболее подвержены оттоку, теперь можно делать общий вывод.

# %% [markdown]
# ## Шаг 5. Сформулируйте выводы и сделайте базовые рекомендации по работе с клиентами

# %% [markdown]
# Итак, подводя итоги первое, что хотелось бы отметить - проект оказался очень интересным.
# В результате работы мы смогли построить модель прогнозирования оттока клиентов, далее мы провели кластеризацию пользователей, если можно выразиться иначе сгруппировали их в пять групп, в результате чего выявили основные группы, которые наиболее подвержены оттоку, как оказалось, это второй кластер , отток там на очень высоком уровне - более 50%, если посмотреть и составить портрет пользователей то это- категория клиентов в возрасте 26 лет, которые посещали клуб впервые и у которых абонемент приобретен на один месяц, клуб они в среднем посещали максимум один раз в неделю. Скорее всего это люди, которые просто решили попробовать ходить в фитнес-центр и возможно после первых нескольких посещений их интерес пропал, поэтому изначально они покупали абонемент на один месяц, также стоит отметить, что они либо проживают либо работают рядом с фитнес-центром.
# Теперь посмотрим на кластеры, которые меньше подвержены оттоку - это первый и четвертый , исходя из результатов нашего исследования можно сказать, что в этих группах клиенты в основном 30-ти лет , они четко делятся на две группы, те кто ходит только на групповые занятия либо те, кто туда не ходит вообще, с момента первого их визита в фитнес центр прошло как минимум 4 месяца и посещают они его достаточно часто, минимум 2 раза в неделю и конечно же именно они приносят самую большую выручку от других услуг фитнес-центра.
# Проанализировав данные можно сделать вывод, о том что основными признаками влияющими на отток могут быть : возраст, факт первоначальной записи в рамках акции «приведи друга» и сотрудничество с компаниями, чьи сотрудники могут получать скидки на абонемент, а также проживание или работа в районе, где находится фитнес-центр как оказалось тоже имеет достаточно сильное влияние.
#
# В конце хотелось бы дать некоторые рекомендации по повышению качества работы с клиентами - возможно стоит отменить акцию «приведи друга», как оказалось она влияет только на отток, перерассмотреть контракты с фирмами, чьи сотрудники посещают фитнес-центр, этот признак тоже оказывает явно не положительное влияние, также быть более внимательными с новыми клиентами, которые проживают рядом с фитнес-центром либо работают, возможно проводить анкетирование клиентов, чтобы понять и проанализировать основные факторы, влияющие на выбор данного клуба.
